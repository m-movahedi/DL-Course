# %% [markdown]
# Please mount your Google drive, and set up your working folder path here.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# start your code here
os.chdir("/content/drive/MyDrive/FSU Courses/Spring2022/DL/Homework9") # change your working folder here
# end your code here

# %% [markdown]
# # Convolutional Neural Networks: Gesture Classification
#
# Welcome to our thrid module! In this notebook, you will:
#
# - Implement a fully functioning ConvNet using TensorFlow
#
# **After this assignment you will be able to:**
#
# - Build and train a ConvNet in TensorFlow for a classification problem
#
# We assume here that you are already familiar with TensorFlow.

# %% [markdown]
# ## 1.0 - TensorFlow model
#
# As usual, we will start by loading in the packages.

# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
import scipy
from PIL import Image
import tensorflow as tf
from tensorflow.python.framework import ops
from tensorflow.keras import datasets, layers, models
from cnn_utils import *

# %matplotlib inline
np.random.seed(1)
tf.random.set_seed(1234)

# %% [markdown]
# Run the next cell to load the "SIGNS" dataset you are going to use.

# %%
# Loading the data (signs)
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# %% [markdown]
# As a reminder, the SIGNS dataset is a collection of 6 signs representing numbers from 0 to 5.
#
# ![alt text](https://drive.google.com/uc?id=1db9mIM_lD4StTKhab9nfLfdCSLjXG3Cf)
# The next cell will show you an example of a labelled image in the dataset. Feel free to change the value of `index` below and re-run to see different examples.

# %%
# Example of a picture
index = 1000
plt.imshow(X_train_orig[index])
print ("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 2

# %% [markdown]
# To get started, let's examine the shapes of your data.

# %%
# what do the following two lines do?
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Next, we will convert the value 0,1,2,3,4,5 to a one-hot column. 
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
conv_layers = {}
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %% [markdown]
# ### 1.1 - Create the convolutional base
#
# In TensorFlow, there are built-in functions that carry out the convolution steps for you.
#
# - **tf.keras.models.Sequential()** groups a linear stack of layers into a neural networt model. You can read the full documentation [here](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential)
# - **tf.keras.layers.Conv2D(filters, kernel_size, strides=(1, 1), padding='valid', activation=None, input_shape=(32, 32, 3), kernel_initializer='glorot_uniform'):** 'filters' specifies the number of filters in this Conv layer. 'kernel_size' indicates the height and the width of the filters, e.g., (3,3) means a 3 by 3 filter. The third input 'strides' represents the strides for the height and the width of the input (n_H_prev, n_W_prev) with default value (1,1). 'padding' can be 'valid'(default) or 'same'. You can choose your activation function in the input 'activation'. You may want to specify your image shape in 'input_shape'. (32,32,3) means this is a 32 by 32 RGB image. 'kernel_initializer' specifies how you want to initialize your filter. You can read the full documentation [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)
# - **tf.keras.layers.MaxPooling2D(pool_size=(f, f), strides=(s,s), padding='valid'):** this function uses a window of size (f, f) and strides of size (s, s) to carry out max pooling over each window. You can read the full documentation [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D)
#
# **Exercise**:
#
# Build the following model: `CONV2D -> MAXPOOL -> CONV2D -> MAXPOOL`. You should use the functions above.
#
# In detail, we will use the following parameters for all the steps:
#
#      - Conv2D: 8 filters with size (4,4), stride 1, padding is "same", activation function is 'Relu', input_shape=(64,64,3), filter initializer is 'glorot_uniform'
#      - Max pool: Use an 8 by 8 filter size and an 8 by 8 stride, padding is "same"
#      - Conv2D: 16 filters with size (2,2), stride 1, padding is "same", activation function is 'Relu', filter initializer is 'glorot_uniform', input shape will be decided automatically
#      - Max pool: Use a 4 by 4 filter size and a 4 by 4 stride, padding is "same"

# %%
# GRADED steps

model = models.Sequential()
#add a conv layer: 8 filters with size (4,4), stride (1,1), padding is 'same', activation function is 'relu', input_shape=(64,64,3), filter initializer is 'glorot_uniform'
model.add(tf.keras.layers.Conv2D(8,
                                 (4,4),
                                 strides=(1,1), 
                                 padding='same', activation='relu', 
                                 input_shape=(64,64,3), 
                                 kernel_initializer='glorot_uniform',
                                 kernel_regularizer=tf.keras.regularizers.L2(0.01)))
#add a MAXPOOL layer: window 8x8, sride (8,8), padding 'same'
model.add(tf.keras.layers.MaxPooling2D(pool_size=(8,8), strides=(8,8), padding='same'))

### START CODE HERE ###
#add the second conv layer: 16 filters with size (2,2), stride (1,1), padding is "same", activation function is 'relu', filter initializer is 'glorot_uniform', input shape will be decided automatically
model.add(model.add(tf.keras.layers.Conv2D(16,
                                 (2,2),
                                 strides=(1,1), 
                                 padding='same', activation='relu',
                                 kernel_initializer='glorot_uniform',
                                 kernel_regularizer=tf.keras.regularizers.L2(0.01))))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(4,4), strides=(4,4), padding='same'))
#add the second MAXPOOL layer: window 4x4, stride (4,4), padding 'same'
model.add(None)
### END CODE HERE ###

model.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-03ae45098411> in <module>()
#      20                                  padding='same', activation='relu',
#      21                                  kernel_initializer='glorot_uniform',
# ---> 22                                  kernel_regularizer=tf.keras.regularizers.L2(0.01))))
#      23 model.add(tf.keras.layers.MaxPooling2D(pool_size=(4,4), strides=(4,4), padding='same'))
#      24 #add the second MAXPOOL layer: window 4x4, stride (4,4), padding 'same'
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     627     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     628     try:
# --> 629       result = method(self, *args, **kwargs)
#     630     finally:
#     631       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py in add(self, layer)
#     176         layer = functional.ModuleWrapper(layer)
#     177     else:
# --> 178       raise TypeError('The added layer must be an instance of class Layer. '
#     179                       f'Received: layer={layer} of type {type(layer)}.')
#     180
#
# TypeError: The added layer must be an instance of class Layer. Received: layer=None of type <class 'NoneType'>.

# %% [markdown]
# **Expected Output**:
#
# ![alt text](https://urldefense.com/v3/__https://drive.google.com/uc?id=16G8b6zw23HkPTSmKKboIVqB_ehiDE9BL__;!!PhOWcWs!lj_KcD0A6Xl-_k4Lj8Ll_SLpdbsvdvk2BUHx7Ca3ALRgep71u_2GAgTSv5pO1_y0ZRQV_so$ )

# %% [markdown]
# ### 1.2 - Add Dense layers on top
# To complete our model, you will feed the last output tensor from the convolutional base (of shape (4, 4, 64)) into one or more Dense layers to perform classification. There are built-in functions that carry out these steps for you.
#
# - **tf.keras.layers.Flatten()**: this function flattens each example into a 1D vector while maintaining the batch-size. It returns a flattened tensor with shape [batch_size, k]. You can read the full documentation [here.](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Flatten)
# - **tf.keras.layers.Dense(num_outputs):** It returns the output computed using a fully connected layer. You shall specify the number of outputs in 'num_outputs'. You can read the full documentation [here.](https://urldefense.com/v3/__https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense)
# In the last function above (`tf.keras.layers.Dense`), the fully connected layer automatically initializes weights in the graph and keeps on training them as you train the model. Hence, you did not need to initialize those weights when initializing the parameters.
#
# **Exercise**:
#
# Build the fully connected (Dense) layer on the Conv base: `CONV2D -> MAXPOOL -> CONV2D -> MAXPOOL -> FLATTEN -> DENSE`. You should use the functions above.
#
# - Flatten the previous output.
# - FULLYCONNECTED (Dense) layer: Apply a fully connected layer with activation function 'softmax'. Multi-class classification problems usually use 'softmax' as the activation function in the output layer if the target output is a 'one-hot' function.

# %%
# add the FLATTEN layer: tf.keras.layers.Flatten()
model.add(tf.keras.layers.Flatten())

### START CODE HERE ###
# Please add a dense layer with 6 neurons, and activation function 'softmax'
model.add(tf.keras.layers.Dense(6,activation='softmax'))
### END CODE HERE ###

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 8)         392
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 8)          0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          528
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 6)                 6150
#
# =================================================================
# Total params: 7,070
# Trainable params: 7,070
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# As you can see, our (2, 2, 16) outputs were flattened into vectors of shape (64) before going through the Dense layer.
#
# **Expected Output**:
#
# ![alt text](https://urldefense.com/v3/__https://drive.google.com/uc?id=15jEv_qKYS0r95tiXQbcuS6PxlBnKcb4R__;!!PhOWcWs!lj_KcD0A6Xl-_k4Lj8Ll_SLpdbsvdvk2BUHx7Ca3ALRgep71u_2GAgTSv5pO1_y0UEdgN_4$ )

# %% [markdown]
# ### 1.3 - Compile and train the model
# When compiling the model, you will specify the optimizer, the loss function, and the metric you are going to use.
#
# - **compile(optimizer=None, loss=None, metrics=None)** You can check the full documentation  [here.](https://urldefense.com/v3/__https://www.tensorflow.org/api_docs/python/tf/keras/Model*compile)
# - **tf.keras.losses.CategoricalCrossentropy()** You can check the full documentation  [here.](https://urldefense.com/v3/__https://www.tensorflow.org/api_docs/python/tf/keras/losses/CategoricalCrossentropy)
#
# **Exercise**: Compile the model using 'tf.keras.optimizers.Adam(learning_rate=None)' as the optimizer, 'tf.keras.losses.CategoricalCrossentropy()' as the loss function, and 'accuracy' as the metrics.
#
# Now, we are ready to train the model. During the training process, you need to specify training input, training output, epoch number and batch size. The samples will be shuffled by default.
#
# -**model.fit(x=None, y=None, batch_size=None, epochs=1,validation_split=0.0)**
#
# **Exercise**: train the model with epoch number no more than 400.
#
# Please adjust the learning_rate in the adam optimizer and the batch_size in 'model.fit' such that the accuracy of the training set is above 92% at the end of the training.

# %%
# GRADED FUNCTION: compile the model 

# Compile the model using 'adam' as the optimizer, 'tf.keras.losses.CategoricalCrossentropy()' as the loss function, and 'accuracy' as the metrics.

### START CODE HERE ### 
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate=0.0005),
          loss=tf.keras.losses.CategoricalCrossentropy(),
          metrics=['accuracy'])
### END CODE HERE ###

# GRADED FUNCTION: train the model 

# train the model with batch size = 64, and epoch number = 100.

### START CODE HERE ### 
history = model.fit(X_train,Y_train,validation_split=0.2,batch_size = 64,  epochs  = 100)
### END CODE HERE ###

## plot the training history
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
#plt.ylim([0.5, 1])
plt.legend(loc='lower right')
#print('The training accuracy is', history.history['accuracy'][-1])
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.4759 - accuracy: 0.9086 - val_loss: 0.4925 - val_accuracy: 0.8750
# Epoch 2/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4634 - accuracy: 0.9144 - val_loss: 0.5182 - val_accuracy: 0.8750
# Epoch 3/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4656 - accuracy: 0.9120 - val_loss: 0.5079 - val_accuracy: 0.8843
# Epoch 4/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.4495 - accuracy: 0.9155 - val_loss: 0.4903 - val_accuracy: 0.8796
# Epoch 5/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4631 - accuracy: 0.9074 - val_loss: 0.5259 - val_accuracy: 0.8796
# Epoch 6/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4477 - accuracy: 0.9190 - val_loss: 0.5038 - val_accuracy: 0.8750
# Epoch 7/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4472 - accuracy: 0.9132 - val_loss: 0.5425 - val_accuracy: 0.8704
# Epoch 8/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4445 - accuracy: 0.9259 - val_loss: 0.5107 - val_accuracy: 0.8750
# Epoch 9/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.4393 - accuracy: 0.9271 - val_loss: 0.4915 - val_accuracy: 0.8750
# Epoch 10/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4292 - accuracy: 0.9225 - val_loss: 0.5052 - val_accuracy: 0.8750
# Epoch 11/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4390 - accuracy: 0.9225 - val_loss: 0.5019 - val_accuracy: 0.8750
# Epoch 12/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.4307 - accuracy: 0.9294 - val_loss: 0.5354 - val_accuracy: 0.8519
# Epoch 13/100
# 14/14 [==============================] - 0s 12ms/step - loss: 0.4448 - accuracy: 0.9201 - val_loss: 0.5532 - val_accuracy: 0.8472
# Epoch 14/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.4375 - accuracy: 0.9190 - val_loss: 0.5072 - val_accuracy: 0.8750
# Epoch 15/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4220 - accuracy: 0.9363 - val_loss: 0.5331 - val_accuracy: 0.8750
# Epoch 16/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4240 - accuracy: 0.9340 - val_loss: 0.5384 - val_accuracy: 0.8657
# Epoch 17/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4326 - accuracy: 0.9306 - val_loss: 0.5128 - val_accuracy: 0.8611
# Epoch 18/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4339 - accuracy: 0.9178 - val_loss: 0.4842 - val_accuracy: 0.8843
# Epoch 19/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4249 - accuracy: 0.9294 - val_loss: 0.4878 - val_accuracy: 0.8750
# Epoch 20/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4242 - accuracy: 0.9317 - val_loss: 0.5132 - val_accuracy: 0.8657
# Epoch 21/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.4184 - accuracy: 0.9363 - val_loss: 0.4877 - val_accuracy: 0.8750
# Epoch 22/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.4179 - accuracy: 0.9352 - val_loss: 0.5131 - val_accuracy: 0.8889
# Epoch 23/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4414 - accuracy: 0.9132 - val_loss: 0.4999 - val_accuracy: 0.8796
# Epoch 24/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.4216 - accuracy: 0.9294 - val_loss: 0.5098 - val_accuracy: 0.8657
# Epoch 25/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4152 - accuracy: 0.9340 - val_loss: 0.4866 - val_accuracy: 0.8750
# Epoch 26/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4145 - accuracy: 0.9375 - val_loss: 0.4999 - val_accuracy: 0.8704
# Epoch 27/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.4032 - accuracy: 0.9456 - val_loss: 0.5341 - val_accuracy: 0.8565
# Epoch 28/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4189 - accuracy: 0.9317 - val_loss: 0.4843 - val_accuracy: 0.8796
# Epoch 29/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4106 - accuracy: 0.9363 - val_loss: 0.5336 - val_accuracy: 0.8472
# Epoch 30/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4205 - accuracy: 0.9259 - val_loss: 0.5186 - val_accuracy: 0.8704
# Epoch 31/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4104 - accuracy: 0.9340 - val_loss: 0.5005 - val_accuracy: 0.8704
# Epoch 32/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4320 - accuracy: 0.9109 - val_loss: 0.5145 - val_accuracy: 0.8843
# Epoch 33/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.4263 - accuracy: 0.9387 - val_loss: 0.4890 - val_accuracy: 0.8611
# Epoch 34/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3944 - accuracy: 0.9387 - val_loss: 0.4975 - val_accuracy: 0.8704
# Epoch 35/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4033 - accuracy: 0.9456 - val_loss: 0.4853 - val_accuracy: 0.8704
# Epoch 36/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3971 - accuracy: 0.9421 - val_loss: 0.5045 - val_accuracy: 0.8704
# Epoch 37/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4001 - accuracy: 0.9421 - val_loss: 0.5267 - val_accuracy: 0.8519
# Epoch 38/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4082 - accuracy: 0.9317 - val_loss: 0.4982 - val_accuracy: 0.8611
# Epoch 39/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.4007 - accuracy: 0.9444 - val_loss: 0.5104 - val_accuracy: 0.8704
# Epoch 40/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3994 - accuracy: 0.9387 - val_loss: 0.5377 - val_accuracy: 0.8611
# Epoch 41/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4015 - accuracy: 0.9444 - val_loss: 0.5085 - val_accuracy: 0.8704
# Epoch 42/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3990 - accuracy: 0.9410 - val_loss: 0.5226 - val_accuracy: 0.8565
# Epoch 43/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3929 - accuracy: 0.9410 - val_loss: 0.4986 - val_accuracy: 0.8611
# Epoch 44/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3870 - accuracy: 0.9352 - val_loss: 0.5050 - val_accuracy: 0.8611
# Epoch 45/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3841 - accuracy: 0.9491 - val_loss: 0.4946 - val_accuracy: 0.8657
# Epoch 46/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3898 - accuracy: 0.9363 - val_loss: 0.5113 - val_accuracy: 0.8750
# Epoch 47/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3990 - accuracy: 0.9363 - val_loss: 0.4901 - val_accuracy: 0.8611
# Epoch 48/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3889 - accuracy: 0.9433 - val_loss: 0.5121 - val_accuracy: 0.8565
# Epoch 49/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.4004 - accuracy: 0.9248 - val_loss: 0.5264 - val_accuracy: 0.8426
# Epoch 50/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3958 - accuracy: 0.9317 - val_loss: 0.4976 - val_accuracy: 0.8843
# Epoch 51/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.4021 - accuracy: 0.9387 - val_loss: 0.5336 - val_accuracy: 0.8750
# Epoch 52/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3919 - accuracy: 0.9433 - val_loss: 0.5453 - val_accuracy: 0.8472
# Epoch 53/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3946 - accuracy: 0.9306 - val_loss: 0.5522 - val_accuracy: 0.8472
# Epoch 54/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3834 - accuracy: 0.9456 - val_loss: 0.5236 - val_accuracy: 0.8611
# Epoch 55/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3730 - accuracy: 0.9560 - val_loss: 0.4985 - val_accuracy: 0.8704
# Epoch 56/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3762 - accuracy: 0.9444 - val_loss: 0.5093 - val_accuracy: 0.8519
# Epoch 57/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3711 - accuracy: 0.9549 - val_loss: 0.5323 - val_accuracy: 0.8426
# Epoch 58/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3776 - accuracy: 0.9525 - val_loss: 0.4922 - val_accuracy: 0.8796
# Epoch 59/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3714 - accuracy: 0.9537 - val_loss: 0.4890 - val_accuracy: 0.8796
# Epoch 60/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3728 - accuracy: 0.9525 - val_loss: 0.4904 - val_accuracy: 0.8657
# Epoch 61/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3765 - accuracy: 0.9456 - val_loss: 0.4807 - val_accuracy: 0.8704
# Epoch 62/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3680 - accuracy: 0.9549 - val_loss: 0.4744 - val_accuracy: 0.8796
# Epoch 63/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3656 - accuracy: 0.9560 - val_loss: 0.4854 - val_accuracy: 0.8750
# Epoch 64/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3730 - accuracy: 0.9491 - val_loss: 0.4909 - val_accuracy: 0.8704
# Epoch 65/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3646 - accuracy: 0.9560 - val_loss: 0.5077 - val_accuracy: 0.8704
# Epoch 66/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3707 - accuracy: 0.9514 - val_loss: 0.5516 - val_accuracy: 0.8380
# Epoch 67/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3826 - accuracy: 0.9375 - val_loss: 0.5597 - val_accuracy: 0.8380
# Epoch 68/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3829 - accuracy: 0.9514 - val_loss: 0.4799 - val_accuracy: 0.8750
# Epoch 69/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3634 - accuracy: 0.9502 - val_loss: 0.4918 - val_accuracy: 0.8889
# Epoch 70/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3741 - accuracy: 0.9479 - val_loss: 0.5037 - val_accuracy: 0.8657
# Epoch 71/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3775 - accuracy: 0.9387 - val_loss: 0.4945 - val_accuracy: 0.8796
# Epoch 72/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3812 - accuracy: 0.9363 - val_loss: 0.5027 - val_accuracy: 0.8611
# Epoch 73/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3728 - accuracy: 0.9479 - val_loss: 0.4870 - val_accuracy: 0.8657
# Epoch 74/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3636 - accuracy: 0.9525 - val_loss: 0.4958 - val_accuracy: 0.8611
# Epoch 75/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3594 - accuracy: 0.9537 - val_loss: 0.5244 - val_accuracy: 0.8565
# Epoch 76/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3643 - accuracy: 0.9525 - val_loss: 0.4902 - val_accuracy: 0.8750
# Epoch 77/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3696 - accuracy: 0.9502 - val_loss: 0.4797 - val_accuracy: 0.8657
# Epoch 78/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3492 - accuracy: 0.9618 - val_loss: 0.4851 - val_accuracy: 0.8611
# Epoch 79/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3538 - accuracy: 0.9549 - val_loss: 0.4823 - val_accuracy: 0.8750
# Epoch 80/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3588 - accuracy: 0.9502 - val_loss: 0.4930 - val_accuracy: 0.8565
# Epoch 81/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3599 - accuracy: 0.9514 - val_loss: 0.4902 - val_accuracy: 0.8796
# Epoch 82/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3533 - accuracy: 0.9583 - val_loss: 0.4949 - val_accuracy: 0.8889
# Epoch 83/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3517 - accuracy: 0.9606 - val_loss: 0.5157 - val_accuracy: 0.8704
# Epoch 84/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3630 - accuracy: 0.9502 - val_loss: 0.5062 - val_accuracy: 0.8565
# Epoch 85/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3499 - accuracy: 0.9572 - val_loss: 0.4956 - val_accuracy: 0.8611
# Epoch 86/100
# 14/14 [==============================] - 0s 16ms/step - loss: 0.3478 - accuracy: 0.9525 - val_loss: 0.5196 - val_accuracy: 0.8565
# Epoch 87/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3420 - accuracy: 0.9595 - val_loss: 0.4836 - val_accuracy: 0.8704
# Epoch 88/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3455 - accuracy: 0.9630 - val_loss: 0.4702 - val_accuracy: 0.8750
# Epoch 89/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3536 - accuracy: 0.9560 - val_loss: 0.4839 - val_accuracy: 0.8704
# Epoch 90/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3523 - accuracy: 0.9537 - val_loss: 0.5105 - val_accuracy: 0.8565
# Epoch 91/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3542 - accuracy: 0.9537 - val_loss: 0.4808 - val_accuracy: 0.8657
# Epoch 92/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3546 - accuracy: 0.9560 - val_loss: 0.5110 - val_accuracy: 0.8565
# Epoch 93/100
# 14/14 [==============================] - 0s 13ms/step - loss: 0.3441 - accuracy: 0.9560 - val_loss: 0.4894 - val_accuracy: 0.8796
# Epoch 94/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3643 - accuracy: 0.9514 - val_loss: 0.4748 - val_accuracy: 0.8889
# Epoch 95/100
# 14/14 [==============================] - 0s 17ms/step - loss: 0.3490 - accuracy: 0.9560 - val_loss: 0.5022 - val_accuracy: 0.8657
# Epoch 96/100
# 14/14 [==============================] - 0s 15ms/step - loss: 0.3437 - accuracy: 0.9560 - val_loss: 0.5245 - val_accuracy: 0.8657
# Epoch 97/100
# 14/14 [==============================] - 0s 18ms/step - loss: 0.3522 - accuracy: 0.9502 - val_loss: 0.5199 - val_accuracy: 0.8426
# Epoch 98/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3688 - accuracy: 0.9363 - val_loss: 0.4894 - val_accuracy: 0.8611
# Epoch 99/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3405 - accuracy: 0.9630 - val_loss: 0.4718 - val_accuracy: 0.8796
# Epoch 100/100
# 14/14 [==============================] - 0s 14ms/step - loss: 0.3373 - accuracy: 0.9606 - val_loss: 0.4787 - val_accuracy: 0.8704

# %%
# Now let's test your model in the test data to see how it works.
test_loss, test_acc = model.evaluate(X_test,  Y_test)
model.save('my_model.h5')
# Out:
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5295 - accuracy: 0.8750

# %% [markdown]
# **Expected output**
# accuracy shall be higher than 0.75.
#
# Congratulations! You have finised the assignment and built a model that recognizes SIGN language with almost 75% accuracy on the test set. You probably want to save your hard work, the trained model, using `model.save('my_model.h5')`. You can later load the saved model by the command `model = load_model('my_model.h5')`
#
# Once again, here's a thumbs up for your work!

# %%
# %pylab inline
import matplotlib.image as mpimg
img = mpimg.imread('/content/drive/MyDrive/FSU Courses/Spring2022/DL/Homework9/images/thumbs_up.jpg')
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-6a2fc7afd05e> in <module>()
#       1 get_ipython().magic('pylab inline')
#       2 import matplotlib.image as mpimg
# ----> 3 img = mpimg.imread('/content/drive/MyDrive/FSU Courses/Spring2022/DL/Homework9/images/thumbs_up.jpg')
#       4 imgplot = plt.imshow(img)
#       5 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in imread(fname, format)
#    1462             raise ValueError('Only know how to handle PNG; with Pillow '
#    1463                              'installed, Matplotlib can handle more images')
# -> 1464         with Image.open(fname) as image:
#    1465             return pil_to_array(image)
#    1466     from matplotlib import _png
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/FSU Courses/Spring2022/DL/Homework9/images/thumbs_up.jpg'

# %% [markdown]
# **Challenge**: Can you try to adjust the hyper-parameters (learning_rate, epochs, batch_size, kernel_regularizer) to improve the accuracy to 85%?
#
# If you wish, feel free to play around with this dataset further. You can actually improve its accuracy by spending more time tuning the hyperparameters, or using regularization (as this model clearly has a high variance). It's quite easy to specify the regularization in the model. Simply, add option 'kernel_regularizer=tf.keras.regularizers.L2(0.001),' to the Conv and Dense layer
