# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/MyDrive/FSU Courses/Spring2022/DL/Mid_term")
# Out:
# Mounted at /content/drive

# %%
#Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##1. Introduction
# The company seeks to automate (in real time) the loan qualifying procedure based on information given by customers while filling out an online application form. It is expected that the development of deep learning models that can help the company predict loan approval in accelerating decision-making process for determining whether an applicant is eligible for a loan or not.

# %% [markdown]
# ##2. Data analysis
# These details are Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History and others. To automate this process, they have given a problem to identify the customers segments, those are eligible for loan amount so that they can specifically target these customers. Here they have provided a partial data set.
#
# We first load the loan data. Please print out the shape of 'loan_data'.

# %%
#Load dataset
loan_data=pd.read_csv('loan.csv')

# start your code here
n_record,n_category=loan_data.shape
# end your code here
print('There are %d records.' % n_record)
print('Every record has %d categories' % n_category)
# Out:
# There are 614 records.
# Every record has 13 categories

# %% [markdown]
# Expected output:
#
# ```
# There are 614 records.
# Every record has 13 categories
# ```
#
# Now, let's print the 1st 20 records of the loan data, and have a better understanding of what the data look like.

# %%
loan_data.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# 13  LP001029    Male      No          0      Graduate            No
# 14  LP001030    Male     Yes          2      Graduate            No
# 15  LP001032    Male      No          0      Graduate            No
# 16  LP001034    Male      No          1  Not Graduate            No
# 17  LP001036  Female      No          0      Graduate            No
# 18  LP001038    Male     Yes          0  Not Graduate            No
# 19  LP001041    Male     Yes          0      Graduate           NaN
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                0.0         NaN             360.0
# 1              4583             1508.0       128.0             360.0
# 2              3000                0.0        66.0             360.0
# 3              2583             2358.0       120.0             360.0
# 4              6000                0.0       141.0             360.0
# 5              5417             4196.0       267.0             360.0
# 6              2333             1516.0        95.0             360.0
# 7              3036             2504.0       158.0             360.0
# 8              4006             1526.0       168.0             360.0
# 9             12841            10968.0       349.0             360.0
# 10             3200              700.0        70.0             360.0
# 11             2500             1840.0       109.0             360.0
# 12             3073             8106.0       200.0             360.0
# 13             1853             2840.0       114.0             360.0
# 14             1299             1086.0        17.0             120.0
# 15             4950                0.0       125.0             360.0
# 16             3596                0.0       100.0             240.0
# 17             3510                0.0        76.0             360.0
# 18             4887                0.0       133.0             360.0
# 19             2600             3500.0       115.0               NaN
#
#     Credit_History Property_Area Loan_Status
# 0              1.0         Urban           Y
# 1              1.0         Rural           N
# 2              1.0         Urban           Y
# 3              1.0         Urban           Y
# 4              1.0         Urban           Y
# 5              1.0         Urban           Y
# 6              1.0         Urban           Y
# 7              0.0     Semiurban           N
# 8              1.0         Urban           Y
# 9              1.0     Semiurban           N
# 10             1.0         Urban           Y
# 11             1.0         Urban           Y
# 12             1.0         Urban           Y
# 13             1.0         Rural           N
# 14             1.0         Urban           Y
# 15             1.0         Urban           Y
# 16             NaN         Urban           Y
# 17             0.0         Urban           N
# 18             1.0         Rural           N
# 19             1.0         Urban           Y

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# We can see that there are 13 categories in the records. Please pay close attention to the data. Sometimes, there are `NaN` values. We will need to fix this later. Right now, Let's analyze the categories one by one.

# %% [markdown]
# ###2.1 Loan ID
# Loan ID is our 1st category. However, this category has no relevance to the approval status. Therefore, we will drop this category. Please print out the first 5 records of the 'loan_data' to make sure that the category 'Loan_ID' is dropped. Hint: check cells above to see how we print the first 20 records.

# %%
loan_data = loan_data.drop(['Loan_ID'], axis = 1)

#start your code here
loan_data.loc[:4]
# end your code here
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y

# %% [markdown]
# Expected output:
# ![alt text](https://drive.google.com/uc?id=1F8Lve6Wx6lYuoMPCNaq_cLEzT1dY9Z__)

# %% [markdown]
# ### 2.2 Gender
# We would like to know among all these 614 records, how many of them are male, how many of them are female, how many of them are null entries.

# %%
gender_count=loan_data.Gender.value_counts(dropna=False) # count different values in 'Gender' category
print(gender_count)
sns.countplot(x="Gender", data=loan_data, palette="hls")
plt.show()

p_male=gender_count['Male']/n_record
p_female=gender_count['Female']/n_record
p_NaN=gender_count[-1]/n_record

print('Percentage of Male: {:.2f}%'.format(p_male*100))
print('Percentage of Female: {:.2f}%'.format(p_female*100))
print('Percentage of missing value: {:.2f}%'.format(p_NaN*100))
# Out:
# Male      489
# Female    112
# NaN        13
# Name: Gender, dtype: int64
# Percentage of Male: 79.64%
# Percentage of Female: 18.24%
# Percentage of missing value: 2.12%

# %% [markdown]
# Conclusion: There are much more male applicants than female applicants. The missing value takes 2.12% of the records, a small portion of the whole records.

# %% [markdown]
# ### 2.3 Married
# Please follow the same idea in section 2.2 to analyze the category 'Married' and make a conclusion at the end of this section.

# %%
def plot_bin(col_):
  
  count_ = loan_data[col_].value_counts(dropna=False) # count different values in 'Gender' category
  print(count_)
  sns.countplot(x=col_, data=loan_data, palette="hls")
  plt.show()
  bin_cat=loan_data[col_].unique()
  for cat in bin_cat:
    p=count_[cat]/n_record
    try:
      print('Percentage of '+cat+': {:.2f}%'.format(p*100))
    except:
      pass
  p_NaN=count_[-1]/n_record
  print('Percentage of missing value: {:.2f}%'.format(p_NaN*100))

# %%
# start your code here
plot_bin('Married')
# end your code here
# Out:
# Yes    398
# No     213
# NaN      3
# Name: Married, dtype: int64
# Percentage of No: 34.69%
# Percentage of Yes: 64.82%
# Percentage of missing value: 0.49%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1GbYJ8nHEgGximpRJMJFwQP4bIiP-luPN)
#
# Please make your conclusion here.

# %% [markdown]
# ###2.4 Dependents
#
# Please follow the same idea in section 2.2 to analyze the category 'Dependents' and make a conclusion at the end of this section.

# %%
# start your code here
plot_bin('Dependents')
# end your code here
# Out:
# 0      345
# 1      102
# 2      101
# 3+      51
# NaN     15
# Name: Dependents, dtype: int64
# Percentage of 0: 56.19%
# Percentage of 1: 16.61%
# Percentage of 2: 16.45%
# Percentage of 3+: 8.31%
# Percentage of missing value: 2.44%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1T05UzKCRuFpxUY4EJKzOZ-MQgFfSsR0v)
#
# Please make your conclusion here.

# %% [markdown]
# ### 2.5 Education
#
# Please follow the same idea in section 2.2 to analyze the category 'Education' and make a conclusion at the end of this section.

# %%
# start your code here
plot_bin('Education')
# end your code here
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
# Percentage of Graduate: 78.18%
# Percentage of Not Graduate: 21.82%
# Percentage of missing value: 21.82%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1uAg12JNPRvQCVZd6tPtYfUZH9Qqs4AR5)
#
# Please make your conclusion here.

# %% [markdown]
# ### 2.6 Self_Employed
#
# Please follow the same idea in section 2.2 to analyze the category 'Self_Employed' and make a conclusion at the end of this section.

# %%
# start your code here
plot_bin('Dependents')
# end your code here
# Out:
# 0      345
# 1      102
# 2      101
# 3+      51
# NaN     15
# Name: Dependents, dtype: int64
# Percentage of 0: 56.19%
# Percentage of 1: 16.61%
# Percentage of 2: 16.45%
# Percentage of 3+: 8.31%
# Percentage of missing value: 2.44%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1SLZFuBWQpXL62a9ppu9i8An4WDruJOmi)
#
# Please make your conclusion here.

# %% [markdown]
# ### 2.7 Applicant income
# The applicant income has a large range of values, and the previous analysis method doesn't apply well in this case. We will use histogram to characterize the distribution of the income.
#
# From the plot, we can see that the income of most applicants are below $10,000, and are not evenly distributed. Normalization is definitly needed for this category.
#
# Besides, the distribution has a thin but long right tail. We will need to treat the right tail to make the distribution more concentrated.

# %%
sns.histplot(loan_data['ApplicantIncome'])
plt.show()

# %% [markdown]
# ### 2.8 Coapplicant income
# Please use the same technique in Section 2.7 to analyze the distribution of the 'CoapplicantIncome' and give a brief discussion of it.

# %%
# start your code here
sns.histplot(loan_data['CoapplicantIncome'])
plt.show()
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1Phqf9WgoHK6OZBuLLWhb8cexvn1bzqye)
#
# Discussion here:

# %% [markdown]
# ### 2.9 Loan amount
#
# Please use the same technique in Section 2.7 to analyze the distribution of the 'LoanAmount' and give a brief discussion of it.

# %%
# start your code here
sns.histplot(loan_data['LoanAmount'])
plt.show()
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1THtXJXErj8rMLcLMVAc1GIsInRajueKG)
#
# Discussion here:

# %% [markdown]
# ### 2.10 Loan_amount_term
#
# Please use the same technique in Section 2.7 to analyze the distribution of the 'Loan_Amount_Term	' and give a brief discussion of it.

# %%
# start your code here
sns.histplot(loan_data['Loan_Amount_Term'])
plt.show()
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1UTKNr75TQKF626JWvAJJ6ItM_dgw3R2J)
#
# Discussion here:

# %% [markdown]
# ### 2.11 Credit history
#
# Please follow the same technique in section 2.7 to analyze the category 'Credit_History' and give a grief discusion.

# %%
# start your code here
sns.histplot(loan_data['Credit_History'])
plt.show()
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1O03n_ZcFpIsr-lubli-g_IPwL6ZhGpr0)
#
# Discussion here:

# %% [markdown]
# ### 2.12 Property area
#
# Please follow the same technique in section 2.2 to analyze the category 'Property_Area' and give a grief discusion.

# %%
# start your code here
plot_bin('Property_Area')

# end your code here
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64
# Percentage of Urban: 32.90%
# Percentage of Rural: 29.15%
# Percentage of Semiurban: 37.95%
# Percentage of missing value: 29.15%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1ZQ0MRWAMe4fFTn9bF-M8ttIVDlJ1kysC)
#
# Discussion here:

# %% [markdown]
# ###2.13 Loan Status
# Please follow the same technique in section 2.2 to analyze the category 'Loan_Status' and give a grief discusion.

# %%
# start your code here
plot_bin('Loan_Status')

# end your code here
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64
# Percentage of Y: 68.73%
# Percentage of N: 31.27%
# Percentage of missing value: 31.27%

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=1KByUcd1F74SAneDWcUgj9_8Vbb-pOGz3)
#
# Discussion here:

# %% [markdown]
# ## 3. Data preprocessing
#
# ### 3.1 Data imputation

# %%
# Checking Null Values.
loan_data.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# There are missing values in Gender, Married, Dependents, Self_Employed, LoanAmount, Loan_Amount_Term, and Credit_History features.
# We will treat the missing values in all the features one by one.
# We can consider these methods to fill the missing values:
#
# * For numerical variables: imputation using mean or median
# * For categorical variables: imputation using mode
#
# There are very few missing values in Gender, Married, Dependents, Credit_History, and Self_Employed features so we can fill them using the mode of the features.
#
# The imputation of 'Gender' is given. Please use the same command to fill the missing values in category 'Married', 'Dependents', 'Self_Employed', and 'Credit_History'.

# %%
loan_data['Gender'].fillna(loan_data['Gender'].mode()[0], inplace=True)
# start your code here
loan_data['Married'].fillna(loan_data['Married'].mode()[0], inplace=True)
loan_data['Dependents'].fillna(loan_data['Dependents'].mode()[0], inplace=True)
loan_data['Self_Employed'].fillna(loan_data['Self_Employed'].mode()[0], inplace=True)
loan_data['Credit_History'].fillna(loan_data['Credit_History'].mode()[0], inplace=True)

# end your code here

# %% [markdown]
# For numerical variables like LoanAmount and Loan_Amount_Term, we fill the missing values with their medians. The imputation of 'Loan_Amount_Term' is given. Please use the same command to fill the missing values in category 'LoanAmount'.

# %%
loan_data['Loan_Amount_Term'].fillna(loan_data['Loan_Amount_Term'].median(),inplace = True)
# start your code here
loan_data['LoanAmount'].fillna(loan_data['LoanAmount'].median(),inplace = True)

# end your code here

# %% [markdown]
# Now, let's print out the data to see whether we fill the missing values with reasonable values. You can compare the table below with the table in the beginning to see the differences.

# %%
loan_data.head(20)
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0     Male      No          0      Graduate            No             5849
# 1     Male     Yes          1      Graduate            No             4583
# 2     Male     Yes          0      Graduate           Yes             3000
# 3     Male     Yes          0  Not Graduate            No             2583
# 4     Male      No          0      Graduate            No             6000
# 5     Male     Yes          2      Graduate           Yes             5417
# 6     Male     Yes          0  Not Graduate            No             2333
# 7     Male     Yes         3+      Graduate            No             3036
# 8     Male     Yes          2      Graduate            No             4006
# 9     Male     Yes          1      Graduate            No            12841
# 10    Male     Yes          2      Graduate            No             3200
# 11    Male     Yes          2      Graduate            No             2500
# 12    Male     Yes          2      Graduate            No             3073
# 13    Male      No          0      Graduate            No             1853
# 14    Male     Yes          2      Graduate            No             1299
# 15    Male      No          0      Graduate            No             4950
# 16    Male      No          1  Not Graduate            No             3596
# 17  Female      No          0      Graduate            No             3510
# 18    Male     Yes          0  Not Graduate            No             4887
# 19    Male     Yes          0      Graduate            No             2600
#
#     CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                 0.0       128.0             360.0             1.0
# 1              1508.0       128.0             360.0             1.0
# 2                 0.0        66.0             360.0             1.0
# 3              2358.0       120.0             360.0             1.0
# 4                 0.0       141.0             360.0             1.0
# 5              4196.0       267.0             360.0             1.0
# 6              1516.0        95.0             360.0             1.0
# 7              2504.0       158.0             360.0             0.0
# 8              1526.0       168.0             360.0             1.0
# 9             10968.0       349.0             360.0             1.0
# 10              700.0        70.0             360.0             1.0
# 11             1840.0       109.0             360.0             1.0
# 12             8106.0       200.0             360.0             1.0
# 13             2840.0       114.0             360.0             1.0
# 14             1086.0        17.0             120.0             1.0
# 15                0.0       125.0             360.0             1.0
# 16                0.0       100.0             240.0             1.0
# 17                0.0        76.0             360.0             0.0
# 18                0.0       133.0             360.0             1.0
# 19             3500.0       115.0             360.0             1.0
#
#    Property_Area Loan_Status
# 0          Urban           Y
# 1          Rural           N
# 2          Urban           Y
# 3          Urban           Y
# 4          Urban           Y
# 5          Urban           Y
# 6          Urban           Y
# 7      Semiurban           N
# 8          Urban           Y
# 9      Semiurban           N
# 10         Urban           Y
# 11         Urban           Y
# 12         Urban           Y
# 13         Rural           N
# 14         Urban           Y
# 15         Urban           Y
# 16         Urban           Y
# 17         Urban           N
# 18         Rural           N
# 19         Urban           Y

# %% [markdown]
# Please check whether all missing values are filled using the command `loan_data.isnull().sum()`. If you have all '0' entries, congratulations! You have finished the data imputation.

# %%
loan_data.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# Expected output:
# ```
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64
# ```

# %% [markdown]
# ### 3.2 Converting categorical values to numbers
#
# Let's first take a look at the data type of the loan data.

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    object
#  1   Married            614 non-null    object
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      614 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    object
#  11  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 57.7+ KB

# %%
loan_data['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3+'], dtype=object)

# %% [markdown]
# From the information provided above, we see that the data type of 7 categories is object. We need to convert them to numbers to train our model.
#
# * For 'Gender' category, 'Male' is mapped to 0, 'Female' is mapped to 1.
#
# Please use the same technique to do the following conversion.
#
# * For 'Married', 'Self_Employed', and 'Loan_Status' category, please map 'No' to 0 and 'Yes' to 1.
#
# * For 'Dependents' category, please map '0' to 0, '1' to 1, '2' to 2, and '3+' to 3.
#
# * For 'Education' category, please map 'Graduate' to 1 and 'Not Graduate' to 0.
#
# * For 'Property_Area' category, please map 'Rural' to 0, 'Semiurban' to 1, and 'Urban' to 2.

# %%
# Converting the categories into numbers using map function.
loan_data['Gender'] = loan_data['Gender'].map({'Male': 0, 'Female': 1})

# start your code here
loan_data['Married'] = loan_data['Married'].map({'Yes': 1, 'No': 0})
loan_data['Self_Employed'] = loan_data['Self_Employed'].map({'Yes': 1, 'No': 0})
loan_data['Loan_Status'] = loan_data['Loan_Status'].map({'Y': 1, 'N': 0})
loan_data['Dependents'] = loan_data['Dependents'].map({'0': 0, '1': 1, '2': 2, '3+': 3})
loan_data['Education'] = loan_data['Education'].map({'Not Graduate': 0, 'Graduate': 1})
loan_data['Property_Area'] = loan_data['Property_Area'].map({'Rural': 0, 'Semiurban': 1, 'Urban': 2})

# end your code here

# %% [markdown]
# Now, let's double check the data types to make sure that we have all numerical entries.

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 57.7 KB

# %% [markdown]
# Expected output:
#
# ```
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 57.7 KB
# ```

# %% [markdown]
# ### 3.3 Right tail treatment
# From section 2.7, 2.8, and 2.9, we see that the income of applicants, coapplicants, and the loan amount have long and thin right tail.
#
# It can be seen that having long and thin right tail often has a significant effect on the mean and standard deviation and hence affecting the distribution. We must take steps to remove the tails from our data sets.
#
# This is called right skewness. One way to remove the skewness is by doing the log transformation. As we take the log transformation, it does not affect the smaller values much but reduces the larger values. So, we get a distribution similar to normal distribution.
# Let’s visualize the effect of log transformation.
#
# Originally, the distribution of applicant income is as below.
#
# ![alt text](https://drive.google.com/uc?id=1UfnWuvx4SV0VLIm5cv0cR1zGteB2g199)
#
# We will apply log transformation to the 'ApplicantIncome' category and recheck the distribution to see the difference.

# %%
epsilon=1
loan_data['ApplicantIncome']=np.log(epsilon+loan_data['ApplicantIncome'])
sns.histplot(loan_data['ApplicantIncome'])
plt.show()

# %% [markdown]
# After the tail treatment, the distribution looks more like a normal distribution. It gives a good base for the next step: data normalization.
#
# Please use the same methods to treat the tails in 'CoapplicantIncome' and 'LoanAmount' category.

# %%
# start your code here
epsilon=1
loan_data['CoapplicantIncome']=np.log(epsilon+loan_data['CoapplicantIncome'])
sns.histplot(loan_data['CoapplicantIncome'])
plt.show()

loan_data['LoanAmount']=np.log(epsilon+loan_data['LoanAmount'])
sns.histplot(loan_data['LoanAmount'])
plt.show()
# end your code here

# %% [markdown]
# Expected output:
#
# ![alt text](https://drive.google.com/uc?id=11JyrjdzswoYkblgYxm8vvD5KssQmxkyw)

# %% [markdown]
# ### 3.4 Other data preprocessing
#
# We emphasized a lot that you will need to preprocess your data before using them to train your model. Now, please think about whether there are other preprocessing that you can do to help you train a good model. If yes, please do it here.

# %%
loan_data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         0        0           0          1              0         8.674197
# 1         0        1           1          1              0         8.430327
# 2         0        1           0          1              1         8.006701
# 3         0        1           0          0              0         7.857094
# 4         0        0           0          1              0         8.699681
# ..      ...      ...         ...        ...            ...              ...
# 609       1        0           0          1              0         7.972811
# 610       0        1           3          1              0         8.320448
# 611       0        1           1          1              0         8.996280
# 612       0        1           2          1              0         8.933796
# 613       1        0           0          1              1         8.430327
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             0.000000    4.859812             360.0             1.0
# 1             7.319202    4.859812             360.0             1.0
# 2             0.000000    4.204693             360.0             1.0
# 3             7.765993    4.795791             360.0             1.0
# 4             0.000000    4.955827             360.0             1.0
# ..                 ...         ...               ...             ...
# 609           0.000000    4.276666             360.0             1.0
# 610           0.000000    3.713572             180.0             1.0
# 611           5.484797    5.537334             360.0             1.0
# 612           0.000000    5.236442             360.0             1.0
# 613           0.000000    4.897840             360.0             0.0
#
#      Property_Area  Loan_Status
# 0                2            1
# 1                0            0
# 2                2            1
# 3                2            1
# 4                2            1
# ..             ...          ...
# 609              0            1
# 610              0            1
# 611              2            1
# 612              2            1
# 613              1            0
#
# [614 rows x 12 columns]

# %%
# start your code here

# end your code here
loan_data.shape
# Out:
# (614, 12)

# %% [markdown]
# ### 3.5 Correlation among different categories
#
# Now let’s look at the correlation between all the numerical variables. We will use the heat map to visualize the correlation. Heatmaps visualize data through variations in coloring. The variables with darker color means their correlation is more.

# %%
plt.figure(figsize=(15,10))
sns.heatmap(loan_data.corr(), vmax=.8, cmap='BuPu',annot=True, fmt='.2g')

# %% [markdown]
# We see a strong correlation between 'Credit_History' and 'Loan_Status', 'LoanAmount' and 'ApplicantIncome', 'CoapplicantIncome' and 'Married', a strong reverse correlation between 'ApplicantIncome' and 'CoapplicantIncom'. When we choose the categories for the training input, these are all elements that need to be considered.

# %% [markdown]
# ### 3.6 Input and output data splitting
#
# We need to predict the 'Loan_Status'. So, our output is 'Loan_Status'. For the input, you can choose as many  relavant categories as you like.
#
# The output data is seperated. As neural network only accept float as the training data set, we use `np.float32` to change the data type to float.
#
# Please choose your input categories using the similar ideas.

# %%
loan_data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         0        0           0          1              0         8.674197
# 1         0        1           1          1              0         8.430327
# 2         0        1           0          1              1         8.006701
# 3         0        1           0          0              0         7.857094
# 4         0        0           0          1              0         8.699681
# ..      ...      ...         ...        ...            ...              ...
# 609       1        0           0          1              0         7.972811
# 610       0        1           3          1              0         8.320448
# 611       0        1           1          1              0         8.996280
# 612       0        1           2          1              0         8.933796
# 613       1        0           0          1              1         8.430327
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             0.000000    4.859812             360.0             1.0
# 1             7.319202    4.859812             360.0             1.0
# 2             0.000000    4.204693             360.0             1.0
# 3             7.765993    4.795791             360.0             1.0
# 4             0.000000    4.955827             360.0             1.0
# ..                 ...         ...               ...             ...
# 609           0.000000    4.276666             360.0             1.0
# 610           0.000000    3.713572             180.0             1.0
# 611           5.484797    5.537334             360.0             1.0
# 612           0.000000    5.236442             360.0             1.0
# 613           0.000000    4.897840             360.0             0.0
#
#      Property_Area  Loan_Status
# 0                2            1
# 1                0            0
# 2                2            1
# 3                2            1
# 4                2            1
# ..             ...          ...
# 609              0            1
# 610              0            1
# 611              2            1
# 612              2            1
# 613              1            0
#
# [614 rows x 12 columns]

# %%
#array = loan_data.values
Y = np.float32(loan_data[['Loan_Status']].values)
Y = np.float32(list(loan_data['Loan_Status']))
Y = np.reshape(Y,(Y.shape[0],1))
# start your code here
X = loan_data[loan_data.columns[1:-1]].to_numpy()
# end your code here
X.dtype
# Out:
# dtype('float64')

# %%
np.asmatrix(loan_data[loan_data.columns[1:-1]].values)
# Out:
# matrix([[  0.,   0.,   1., ..., 360.,   1.,   2.],
#         [  1.,   1.,   1., ..., 360.,   1.,   0.],
#         [  1.,   0.,   1., ..., 360.,   1.,   2.],
#         ...,
#         [  1.,   1.,   1., ..., 360.,   1.,   2.],
#         [  1.,   2.,   1., ..., 360.,   1.,   2.],
#         [  0.,   0.,   1., ..., 360.,   0.,   1.]])

# %% [markdown]
# Expected output:
# ```
# dtype('float32')
# ```

# %% [markdown]
# ### 3.7 Training and testing data splitting
#
# In our lecture, we mentioned that if you have a small dataset (<2000 samples). It is suggested to use 20% of it for testing purpose. It can be easily realized using sklearn library.

# %%
from sklearn import model_selection
x_train, x_test, y_train, y_test = model_selection.train_test_split(X, Y, test_size=0.2, random_state=1234)

# %% [markdown]
# ## 4 Building Neural network
#
# Please use what we learned before to build your neural network. You have the freedome to choose your network structure. Just keep it in mind that the number of neurons in the input layer and the output layer should be the same as the size of your input and output data for each sample. Besides, since this is a binary classification problem, the activation function in the output layer needs to be 'sigmoid' function.

# %%
np.any(np.isnan(x_train))
# Out:
# False

# %%
import tensorflow as tf

# start your code here
model=tf.keras.Sequential([
    #Input layer                      
    tf.keras.layers.Input(shape=(x_train.shape[1])), # Set how many elements are there in every training image?

    #Start adding hidden layers  
    tf.keras.layers.Dense(15,activation='relu',kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=tf.keras.regularizers.L2(0.001)), # Please set your neuron numbers, activation function and so on. 
    #please feel free to add more hidden layers here. 
    tf.keras.layers.Dense(15,activation='relu',kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=tf.keras.regularizers.L2(0.001)),
    #tf.keras.layers.Dropout(0.35),
    tf.keras.layers.Dense(15,activation='relu',kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=tf.keras.regularizers.L2(0.001)),
    #tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(15,activation='relu',kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=tf.keras.regularizers.L2(0.001)),
    #tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(15,activation='relu',kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=tf.keras.regularizers.L2(0.001)),
    # End adding hidden layers 

    #output layer                   
    tf.keras.layers.Dense(1, activation='sigmoid',kernel_initializer='glorot_uniform', bias_initializer='zeros') # Set how many elements are there in every training output
            
])
# end your code here
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 15)                165
#
#  dense_7 (Dense)             (None, 15)                240
#
#  dense_8 (Dense)             (None, 15)                240
#
#  dense_9 (Dense)             (None, 15)                240
#
#  dense_10 (Dense)            (None, 15)                240
#
#  dense_11 (Dense)            (None, 1)                 16
#
# =================================================================
# Total params: 1,141
# Trainable params: 1,141
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5. Compiling and training your neural network
# Please use what you learned before to compile and train your neural network.

# %%
# start your code here
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss=tf.keras.losses.BinaryCrossentropy(), 
              metrics=['accuracy'],
              )
history = model.fit( x_train ,
                    y_train,
                    #batch_size=6,
                    validation_split=0.1,
                    epochs=1000
                    )
#end your code here
# Out:
# Epoch 1/1000
# 14/14 [==============================] - 1s 20ms/step - loss: 0.7310 - accuracy: 0.6485 - val_loss: 0.6907 - val_accuracy: 0.7200
# Epoch 2/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7153 - accuracy: 0.6848 - val_loss: 0.6831 - val_accuracy: 0.7200
# Epoch 3/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7043 - accuracy: 0.6848 - val_loss: 0.6833 - val_accuracy: 0.7200
# Epoch 4/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7004 - accuracy: 0.6825 - val_loss: 0.6816 - val_accuracy: 0.7200
# Epoch 5/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7021 - accuracy: 0.6848 - val_loss: 0.6842 - val_accuracy: 0.7200
# Epoch 6/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7003 - accuracy: 0.6825 - val_loss: 0.6806 - val_accuracy: 0.7200
# Epoch 7/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7027 - accuracy: 0.6848 - val_loss: 0.6872 - val_accuracy: 0.7200
# Epoch 8/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7004 - accuracy: 0.6848 - val_loss: 0.6895 - val_accuracy: 0.7200
# Epoch 9/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7169 - accuracy: 0.6848 - val_loss: 0.7043 - val_accuracy: 0.7000
# Epoch 10/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7030 - accuracy: 0.6825 - val_loss: 0.6792 - val_accuracy: 0.7200
# Epoch 11/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7000 - accuracy: 0.6848 - val_loss: 0.6787 - val_accuracy: 0.7200
# Epoch 12/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7047 - accuracy: 0.6848 - val_loss: 0.6779 - val_accuracy: 0.7200
# Epoch 13/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6970 - accuracy: 0.6803 - val_loss: 0.6801 - val_accuracy: 0.7200
# Epoch 14/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7025 - accuracy: 0.6871 - val_loss: 0.6887 - val_accuracy: 0.7200
# Epoch 15/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7067 - accuracy: 0.6803 - val_loss: 0.6834 - val_accuracy: 0.7200
# Epoch 16/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6978 - accuracy: 0.6848 - val_loss: 0.6915 - val_accuracy: 0.7200
# Epoch 17/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6977 - accuracy: 0.6848 - val_loss: 0.6759 - val_accuracy: 0.7200
# Epoch 18/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6947 - accuracy: 0.6848 - val_loss: 0.6860 - val_accuracy: 0.7200
# Epoch 19/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7001 - accuracy: 0.6825 - val_loss: 0.6782 - val_accuracy: 0.7200
# Epoch 20/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6989 - accuracy: 0.6848 - val_loss: 0.6755 - val_accuracy: 0.7200
# Epoch 21/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6950 - accuracy: 0.6848 - val_loss: 0.6777 - val_accuracy: 0.7200
# Epoch 22/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6964 - accuracy: 0.6848 - val_loss: 0.6736 - val_accuracy: 0.7200
# Epoch 23/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6944 - accuracy: 0.6825 - val_loss: 0.6732 - val_accuracy: 0.7200
# Epoch 24/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6951 - accuracy: 0.6848 - val_loss: 0.6824 - val_accuracy: 0.7200
# Epoch 25/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6925 - accuracy: 0.6871 - val_loss: 0.6725 - val_accuracy: 0.7200
# Epoch 26/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6984 - accuracy: 0.6848 - val_loss: 0.6732 - val_accuracy: 0.7200
# Epoch 27/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7019 - accuracy: 0.6803 - val_loss: 0.6728 - val_accuracy: 0.7200
# Epoch 28/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6908 - accuracy: 0.6825 - val_loss: 0.6811 - val_accuracy: 0.7200
# Epoch 29/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6939 - accuracy: 0.6848 - val_loss: 0.6713 - val_accuracy: 0.7200
# Epoch 30/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6964 - accuracy: 0.6757 - val_loss: 0.6750 - val_accuracy: 0.7200
# Epoch 31/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6982 - accuracy: 0.6848 - val_loss: 0.6829 - val_accuracy: 0.7200
# Epoch 32/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6977 - accuracy: 0.6871 - val_loss: 0.6701 - val_accuracy: 0.7200
# Epoch 33/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7057 - accuracy: 0.6780 - val_loss: 0.6748 - val_accuracy: 0.7200
# Epoch 34/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6944 - accuracy: 0.6848 - val_loss: 0.6804 - val_accuracy: 0.7200
# Epoch 35/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6931 - accuracy: 0.6848 - val_loss: 0.6688 - val_accuracy: 0.7200
# Epoch 36/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6995 - accuracy: 0.6757 - val_loss: 0.6791 - val_accuracy: 0.7200
# Epoch 37/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.7105 - accuracy: 0.6871 - val_loss: 0.6962 - val_accuracy: 0.7200
# Epoch 38/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6951 - accuracy: 0.6803 - val_loss: 0.6700 - val_accuracy: 0.7200
# Epoch 39/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6963 - accuracy: 0.6825 - val_loss: 0.6678 - val_accuracy: 0.7200
# Epoch 40/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6979 - accuracy: 0.6871 - val_loss: 0.6834 - val_accuracy: 0.7200
# Epoch 41/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6874 - accuracy: 0.6825 - val_loss: 0.6679 - val_accuracy: 0.7200
# Epoch 42/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6913 - accuracy: 0.6871 - val_loss: 0.6664 - val_accuracy: 0.7200
# Epoch 43/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6883 - accuracy: 0.6848 - val_loss: 0.6676 - val_accuracy: 0.7200
# Epoch 44/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6871 - accuracy: 0.6848 - val_loss: 0.6654 - val_accuracy: 0.7200
# Epoch 45/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6903 - accuracy: 0.6871 - val_loss: 0.6735 - val_accuracy: 0.7200
# Epoch 46/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6859 - accuracy: 0.6848 - val_loss: 0.6649 - val_accuracy: 0.7200
# Epoch 47/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6876 - accuracy: 0.6871 - val_loss: 0.6654 - val_accuracy: 0.7200
# Epoch 48/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6830 - accuracy: 0.6848 - val_loss: 0.6702 - val_accuracy: 0.7200
# Epoch 49/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6898 - accuracy: 0.6848 - val_loss: 0.6722 - val_accuracy: 0.7200
# Epoch 50/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6872 - accuracy: 0.6848 - val_loss: 0.6669 - val_accuracy: 0.7200
# Epoch 51/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6876 - accuracy: 0.6825 - val_loss: 0.6638 - val_accuracy: 0.7200
# Epoch 52/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6941 - accuracy: 0.6825 - val_loss: 0.6635 - val_accuracy: 0.7200
# Epoch 53/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6880 - accuracy: 0.6848 - val_loss: 0.6668 - val_accuracy: 0.7200
# Epoch 54/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6889 - accuracy: 0.6848 - val_loss: 0.6732 - val_accuracy: 0.7200
# Epoch 55/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6791 - accuracy: 0.6893 - val_loss: 0.6806 - val_accuracy: 0.7200
# Epoch 56/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6841 - accuracy: 0.6803 - val_loss: 0.6692 - val_accuracy: 0.7200
# Epoch 57/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6927 - accuracy: 0.6848 - val_loss: 0.6738 - val_accuracy: 0.7200
# Epoch 58/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6821 - accuracy: 0.6871 - val_loss: 0.6612 - val_accuracy: 0.7200
# Epoch 59/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6825 - accuracy: 0.6848 - val_loss: 0.6607 - val_accuracy: 0.7200
# Epoch 60/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6823 - accuracy: 0.6848 - val_loss: 0.6603 - val_accuracy: 0.7200
# Epoch 61/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6874 - accuracy: 0.6825 - val_loss: 0.6601 - val_accuracy: 0.7200
# Epoch 62/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6841 - accuracy: 0.6871 - val_loss: 0.6701 - val_accuracy: 0.7200
# Epoch 63/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6817 - accuracy: 0.6848 - val_loss: 0.6606 - val_accuracy: 0.7200
# Epoch 64/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6831 - accuracy: 0.6848 - val_loss: 0.6593 - val_accuracy: 0.7200
# Epoch 65/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6806 - accuracy: 0.6848 - val_loss: 0.6603 - val_accuracy: 0.7200
# Epoch 66/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6792 - accuracy: 0.6848 - val_loss: 0.6591 - val_accuracy: 0.7200
# Epoch 67/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6875 - accuracy: 0.6848 - val_loss: 0.6614 - val_accuracy: 0.7200
# Epoch 68/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6810 - accuracy: 0.6871 - val_loss: 0.6781 - val_accuracy: 0.7200
# Epoch 69/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6902 - accuracy: 0.6871 - val_loss: 0.6663 - val_accuracy: 0.7200
# Epoch 70/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6795 - accuracy: 0.6825 - val_loss: 0.6612 - val_accuracy: 0.7200
# Epoch 71/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6815 - accuracy: 0.6848 - val_loss: 0.6579 - val_accuracy: 0.7200
# Epoch 72/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6779 - accuracy: 0.6848 - val_loss: 0.6583 - val_accuracy: 0.7200
# Epoch 73/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6765 - accuracy: 0.6848 - val_loss: 0.6567 - val_accuracy: 0.7200
# Epoch 74/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6750 - accuracy: 0.6848 - val_loss: 0.6589 - val_accuracy: 0.7200
# Epoch 75/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6765 - accuracy: 0.6871 - val_loss: 0.6563 - val_accuracy: 0.7200
# Epoch 76/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6767 - accuracy: 0.6871 - val_loss: 0.6569 - val_accuracy: 0.7200
# Epoch 77/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6756 - accuracy: 0.6848 - val_loss: 0.6597 - val_accuracy: 0.7200
# Epoch 78/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6781 - accuracy: 0.6848 - val_loss: 0.6552 - val_accuracy: 0.7200
# Epoch 79/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6778 - accuracy: 0.6871 - val_loss: 0.6602 - val_accuracy: 0.7200
# Epoch 80/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6934 - accuracy: 0.6803 - val_loss: 0.6998 - val_accuracy: 0.7200
# Epoch 81/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7003 - accuracy: 0.6825 - val_loss: 0.6884 - val_accuracy: 0.7200
# Epoch 82/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6778 - accuracy: 0.6848 - val_loss: 0.6537 - val_accuracy: 0.7200
# Epoch 83/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6747 - accuracy: 0.6871 - val_loss: 0.6535 - val_accuracy: 0.7200
# Epoch 84/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6742 - accuracy: 0.6871 - val_loss: 0.6596 - val_accuracy: 0.7200
# Epoch 85/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6784 - accuracy: 0.6871 - val_loss: 0.6722 - val_accuracy: 0.7200
# Epoch 86/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6884 - accuracy: 0.6871 - val_loss: 0.6571 - val_accuracy: 0.7200
# Epoch 87/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6716 - accuracy: 0.6871 - val_loss: 0.6534 - val_accuracy: 0.7200
# Epoch 88/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6758 - accuracy: 0.6871 - val_loss: 0.6520 - val_accuracy: 0.7200
# Epoch 89/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6793 - accuracy: 0.6871 - val_loss: 0.6544 - val_accuracy: 0.7200
# Epoch 90/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6889 - accuracy: 0.6825 - val_loss: 0.6578 - val_accuracy: 0.7200
# Epoch 91/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6942 - accuracy: 0.6893 - val_loss: 0.6612 - val_accuracy: 0.7200
# Epoch 92/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6724 - accuracy: 0.6871 - val_loss: 0.6508 - val_accuracy: 0.7200
# Epoch 93/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6753 - accuracy: 0.6871 - val_loss: 0.6509 - val_accuracy: 0.7200
# Epoch 94/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6789 - accuracy: 0.6871 - val_loss: 0.6505 - val_accuracy: 0.7200
# Epoch 95/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6729 - accuracy: 0.6871 - val_loss: 0.6549 - val_accuracy: 0.7200
# Epoch 96/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6724 - accuracy: 0.6871 - val_loss: 0.6510 - val_accuracy: 0.7200
# Epoch 97/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6699 - accuracy: 0.6871 - val_loss: 0.6495 - val_accuracy: 0.7200
# Epoch 98/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6753 - accuracy: 0.6871 - val_loss: 0.6591 - val_accuracy: 0.7200
# Epoch 99/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6699 - accuracy: 0.6871 - val_loss: 0.6491 - val_accuracy: 0.7200
# Epoch 100/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6719 - accuracy: 0.6871 - val_loss: 0.6489 - val_accuracy: 0.7200
# Epoch 101/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6705 - accuracy: 0.6871 - val_loss: 0.6638 - val_accuracy: 0.7200
# Epoch 102/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6789 - accuracy: 0.6871 - val_loss: 0.6542 - val_accuracy: 0.7200
# Epoch 103/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6747 - accuracy: 0.6848 - val_loss: 0.6502 - val_accuracy: 0.7200
# Epoch 104/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6711 - accuracy: 0.6871 - val_loss: 0.6599 - val_accuracy: 0.7200
# Epoch 105/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6738 - accuracy: 0.6893 - val_loss: 0.6548 - val_accuracy: 0.7200
# Epoch 106/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6741 - accuracy: 0.6871 - val_loss: 0.6663 - val_accuracy: 0.7200
# Epoch 107/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6866 - accuracy: 0.6871 - val_loss: 0.6471 - val_accuracy: 0.7200
# Epoch 108/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6738 - accuracy: 0.6871 - val_loss: 0.6479 - val_accuracy: 0.7200
# Epoch 109/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6882 - accuracy: 0.6848 - val_loss: 0.6840 - val_accuracy: 0.7200
# Epoch 110/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6705 - accuracy: 0.6848 - val_loss: 0.6492 - val_accuracy: 0.7200
# Epoch 111/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6674 - accuracy: 0.6871 - val_loss: 0.6530 - val_accuracy: 0.7200
# Epoch 112/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6694 - accuracy: 0.6871 - val_loss: 0.6500 - val_accuracy: 0.7200
# Epoch 113/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6840 - accuracy: 0.6871 - val_loss: 0.6464 - val_accuracy: 0.7200
# Epoch 114/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6751 - accuracy: 0.6848 - val_loss: 0.6457 - val_accuracy: 0.7200
# Epoch 115/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6772 - accuracy: 0.6871 - val_loss: 0.6517 - val_accuracy: 0.7200
# Epoch 116/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6651 - accuracy: 0.6871 - val_loss: 0.6453 - val_accuracy: 0.7200
# Epoch 117/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6682 - accuracy: 0.6893 - val_loss: 0.6456 - val_accuracy: 0.7200
# Epoch 118/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6697 - accuracy: 0.6871 - val_loss: 0.6514 - val_accuracy: 0.7200
# Epoch 119/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6709 - accuracy: 0.6871 - val_loss: 0.6532 - val_accuracy: 0.7200
# Epoch 120/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6865 - accuracy: 0.6848 - val_loss: 0.6869 - val_accuracy: 0.7200
# Epoch 121/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6700 - accuracy: 0.6871 - val_loss: 0.6548 - val_accuracy: 0.7200
# Epoch 122/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6745 - accuracy: 0.6893 - val_loss: 0.6452 - val_accuracy: 0.7200
# Epoch 123/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6677 - accuracy: 0.6871 - val_loss: 0.6449 - val_accuracy: 0.7200
# Epoch 124/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6669 - accuracy: 0.6871 - val_loss: 0.6435 - val_accuracy: 0.7200
# Epoch 125/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6707 - accuracy: 0.6871 - val_loss: 0.6654 - val_accuracy: 0.7200
# Epoch 126/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6733 - accuracy: 0.6871 - val_loss: 0.6495 - val_accuracy: 0.7200
# Epoch 127/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6721 - accuracy: 0.6871 - val_loss: 0.6433 - val_accuracy: 0.7200
# Epoch 128/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6663 - accuracy: 0.6871 - val_loss: 0.6449 - val_accuracy: 0.7200
# Epoch 129/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6664 - accuracy: 0.6871 - val_loss: 0.6447 - val_accuracy: 0.7200
# Epoch 130/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6636 - accuracy: 0.6871 - val_loss: 0.6421 - val_accuracy: 0.7200
# Epoch 131/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6646 - accuracy: 0.6871 - val_loss: 0.6429 - val_accuracy: 0.7200
# Epoch 132/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6666 - accuracy: 0.6871 - val_loss: 0.6472 - val_accuracy: 0.7200
# Epoch 133/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6694 - accuracy: 0.6871 - val_loss: 0.6467 - val_accuracy: 0.7200
# Epoch 134/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6636 - accuracy: 0.6871 - val_loss: 0.6446 - val_accuracy: 0.7200
# Epoch 135/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6627 - accuracy: 0.6871 - val_loss: 0.6472 - val_accuracy: 0.7200
# Epoch 136/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6723 - accuracy: 0.6871 - val_loss: 0.6485 - val_accuracy: 0.7200
# Epoch 137/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6819 - accuracy: 0.6848 - val_loss: 0.6463 - val_accuracy: 0.7200
# Epoch 138/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6674 - accuracy: 0.6848 - val_loss: 0.6548 - val_accuracy: 0.7200
# Epoch 139/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6712 - accuracy: 0.6871 - val_loss: 0.6720 - val_accuracy: 0.7200
# Epoch 140/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6704 - accuracy: 0.6871 - val_loss: 0.6488 - val_accuracy: 0.7200
# Epoch 141/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6631 - accuracy: 0.6871 - val_loss: 0.6404 - val_accuracy: 0.7200
# Epoch 142/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6628 - accuracy: 0.6893 - val_loss: 0.6622 - val_accuracy: 0.7200
# Epoch 143/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6732 - accuracy: 0.6871 - val_loss: 0.6533 - val_accuracy: 0.7200
# Epoch 144/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6645 - accuracy: 0.6871 - val_loss: 0.6455 - val_accuracy: 0.7200
# Epoch 145/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6621 - accuracy: 0.6871 - val_loss: 0.6416 - val_accuracy: 0.7200
# Epoch 146/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6632 - accuracy: 0.6871 - val_loss: 0.6414 - val_accuracy: 0.7200
# Epoch 147/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6621 - accuracy: 0.6871 - val_loss: 0.6429 - val_accuracy: 0.7200
# Epoch 148/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6611 - accuracy: 0.6871 - val_loss: 0.6405 - val_accuracy: 0.7200
# Epoch 149/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6610 - accuracy: 0.6871 - val_loss: 0.6524 - val_accuracy: 0.7200
# Epoch 150/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6693 - accuracy: 0.6871 - val_loss: 0.6424 - val_accuracy: 0.7200
# Epoch 151/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6637 - accuracy: 0.6871 - val_loss: 0.6405 - val_accuracy: 0.7200
# Epoch 152/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6589 - accuracy: 0.6871 - val_loss: 0.6397 - val_accuracy: 0.7200
# Epoch 153/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6683 - accuracy: 0.6871 - val_loss: 0.6476 - val_accuracy: 0.7200
# Epoch 154/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6600 - accuracy: 0.6871 - val_loss: 0.6375 - val_accuracy: 0.7200
# Epoch 155/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6629 - accuracy: 0.6871 - val_loss: 0.6397 - val_accuracy: 0.7200
# Epoch 156/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6648 - accuracy: 0.6871 - val_loss: 0.6467 - val_accuracy: 0.7200
# Epoch 157/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6571 - accuracy: 0.6871 - val_loss: 0.6427 - val_accuracy: 0.7200
# Epoch 158/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6652 - accuracy: 0.6871 - val_loss: 0.6369 - val_accuracy: 0.7200
# Epoch 159/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6599 - accuracy: 0.6871 - val_loss: 0.6366 - val_accuracy: 0.7200
# Epoch 160/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6614 - accuracy: 0.6871 - val_loss: 0.6405 - val_accuracy: 0.7200
# Epoch 161/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6632 - accuracy: 0.6871 - val_loss: 0.6447 - val_accuracy: 0.7200
# Epoch 162/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6601 - accuracy: 0.6871 - val_loss: 0.6419 - val_accuracy: 0.7200
# Epoch 163/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6583 - accuracy: 0.6871 - val_loss: 0.6383 - val_accuracy: 0.7200
# Epoch 164/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6600 - accuracy: 0.6871 - val_loss: 0.6379 - val_accuracy: 0.7200
# Epoch 165/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6616 - accuracy: 0.6871 - val_loss: 0.6365 - val_accuracy: 0.7200
# Epoch 166/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6577 - accuracy: 0.6871 - val_loss: 0.6416 - val_accuracy: 0.7200
# Epoch 167/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6645 - accuracy: 0.6871 - val_loss: 0.6354 - val_accuracy: 0.7200
# Epoch 168/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6568 - accuracy: 0.6871 - val_loss: 0.6393 - val_accuracy: 0.7200
# Epoch 169/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6586 - accuracy: 0.6871 - val_loss: 0.6373 - val_accuracy: 0.7200
# Epoch 170/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6560 - accuracy: 0.6871 - val_loss: 0.6368 - val_accuracy: 0.7200
# Epoch 171/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6554 - accuracy: 0.6871 - val_loss: 0.6365 - val_accuracy: 0.7200
# Epoch 172/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6567 - accuracy: 0.6871 - val_loss: 0.6424 - val_accuracy: 0.7200
# Epoch 173/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6582 - accuracy: 0.6871 - val_loss: 0.6368 - val_accuracy: 0.7200
# Epoch 174/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6537 - accuracy: 0.6871 - val_loss: 0.6341 - val_accuracy: 0.7200
# Epoch 175/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6538 - accuracy: 0.6871 - val_loss: 0.6358 - val_accuracy: 0.7200
# Epoch 176/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6547 - accuracy: 0.6871 - val_loss: 0.6357 - val_accuracy: 0.7200
# Epoch 177/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6541 - accuracy: 0.6871 - val_loss: 0.6357 - val_accuracy: 0.7200
# Epoch 178/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6565 - accuracy: 0.6871 - val_loss: 0.6329 - val_accuracy: 0.7200
# Epoch 179/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6521 - accuracy: 0.6871 - val_loss: 0.6363 - val_accuracy: 0.7200
# Epoch 180/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6552 - accuracy: 0.6871 - val_loss: 0.6326 - val_accuracy: 0.7200
# Epoch 181/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6555 - accuracy: 0.6871 - val_loss: 0.6330 - val_accuracy: 0.7200
# Epoch 182/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6523 - accuracy: 0.6871 - val_loss: 0.6320 - val_accuracy: 0.7200
# Epoch 183/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6571 - accuracy: 0.6871 - val_loss: 0.6321 - val_accuracy: 0.7200
# Epoch 184/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6551 - accuracy: 0.6871 - val_loss: 0.6333 - val_accuracy: 0.7200
# Epoch 185/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6613 - accuracy: 0.6871 - val_loss: 0.6505 - val_accuracy: 0.7200
# Epoch 186/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6633 - accuracy: 0.6871 - val_loss: 0.6359 - val_accuracy: 0.7200
# Epoch 187/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6622 - accuracy: 0.6893 - val_loss: 0.6339 - val_accuracy: 0.7200
# Epoch 188/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6553 - accuracy: 0.6871 - val_loss: 0.6462 - val_accuracy: 0.7200
# Epoch 189/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6589 - accuracy: 0.6871 - val_loss: 0.6340 - val_accuracy: 0.7200
# Epoch 190/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6519 - accuracy: 0.6871 - val_loss: 0.6333 - val_accuracy: 0.7200
# Epoch 191/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6512 - accuracy: 0.6871 - val_loss: 0.6364 - val_accuracy: 0.7200
# Epoch 192/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6521 - accuracy: 0.6871 - val_loss: 0.6313 - val_accuracy: 0.7200
# Epoch 193/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6502 - accuracy: 0.6871 - val_loss: 0.6344 - val_accuracy: 0.7200
# Epoch 194/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6558 - accuracy: 0.6871 - val_loss: 0.6301 - val_accuracy: 0.7200
# Epoch 195/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6585 - accuracy: 0.6871 - val_loss: 0.6367 - val_accuracy: 0.7200
# Epoch 196/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6566 - accuracy: 0.6871 - val_loss: 0.6363 - val_accuracy: 0.7200
# Epoch 197/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6521 - accuracy: 0.6871 - val_loss: 0.6302 - val_accuracy: 0.7200
# Epoch 198/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6621 - accuracy: 0.6871 - val_loss: 0.6323 - val_accuracy: 0.7200
# Epoch 199/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6697 - accuracy: 0.6871 - val_loss: 0.6542 - val_accuracy: 0.7200
# Epoch 200/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6545 - accuracy: 0.6893 - val_loss: 0.6304 - val_accuracy: 0.7200
# Epoch 201/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6485 - accuracy: 0.6871 - val_loss: 0.6349 - val_accuracy: 0.7200
# Epoch 202/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6571 - accuracy: 0.6871 - val_loss: 0.6411 - val_accuracy: 0.7200
# Epoch 203/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6551 - accuracy: 0.6871 - val_loss: 0.6301 - val_accuracy: 0.7200
# Epoch 204/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6490 - accuracy: 0.6871 - val_loss: 0.6289 - val_accuracy: 0.7200
# Epoch 205/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6492 - accuracy: 0.6871 - val_loss: 0.6315 - val_accuracy: 0.7200
# Epoch 206/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6555 - accuracy: 0.6871 - val_loss: 0.6336 - val_accuracy: 0.7200
# Epoch 207/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6540 - accuracy: 0.6871 - val_loss: 0.6388 - val_accuracy: 0.7200
# Epoch 208/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6534 - accuracy: 0.6871 - val_loss: 0.6311 - val_accuracy: 0.7200
# Epoch 209/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6484 - accuracy: 0.6871 - val_loss: 0.6337 - val_accuracy: 0.7200
# Epoch 210/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6471 - accuracy: 0.6871 - val_loss: 0.6352 - val_accuracy: 0.7200
# Epoch 211/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6493 - accuracy: 0.6871 - val_loss: 0.6463 - val_accuracy: 0.7200
# Epoch 212/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6636 - accuracy: 0.6871 - val_loss: 0.6325 - val_accuracy: 0.7200
# Epoch 213/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6509 - accuracy: 0.6893 - val_loss: 0.6321 - val_accuracy: 0.7200
# Epoch 214/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6564 - accuracy: 0.6893 - val_loss: 0.6780 - val_accuracy: 0.7600
# Epoch 215/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6554 - accuracy: 0.6939 - val_loss: 0.6265 - val_accuracy: 0.7200
# Epoch 216/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6501 - accuracy: 0.6871 - val_loss: 0.6440 - val_accuracy: 0.7200
# Epoch 217/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6517 - accuracy: 0.6871 - val_loss: 0.6335 - val_accuracy: 0.7200
# Epoch 218/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6574 - accuracy: 0.6871 - val_loss: 0.6266 - val_accuracy: 0.7200
# Epoch 219/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6525 - accuracy: 0.6871 - val_loss: 0.6374 - val_accuracy: 0.7200
# Epoch 220/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6599 - accuracy: 0.6961 - val_loss: 0.6374 - val_accuracy: 0.7200
# Epoch 221/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6589 - accuracy: 0.6893 - val_loss: 0.6258 - val_accuracy: 0.7200
# Epoch 222/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6455 - accuracy: 0.6871 - val_loss: 0.6253 - val_accuracy: 0.7200
# Epoch 223/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6479 - accuracy: 0.6871 - val_loss: 0.6276 - val_accuracy: 0.7200
# Epoch 224/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6461 - accuracy: 0.6871 - val_loss: 0.6247 - val_accuracy: 0.7200
# Epoch 225/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6473 - accuracy: 0.6871 - val_loss: 0.6253 - val_accuracy: 0.7200
# Epoch 226/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6523 - accuracy: 0.6871 - val_loss: 0.6345 - val_accuracy: 0.7200
# Epoch 227/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6453 - accuracy: 0.6871 - val_loss: 0.6248 - val_accuracy: 0.7200
# Epoch 228/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6418 - accuracy: 0.6871 - val_loss: 0.6412 - val_accuracy: 0.7200
# Epoch 229/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6674 - accuracy: 0.6871 - val_loss: 0.6293 - val_accuracy: 0.7200
# Epoch 230/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6443 - accuracy: 0.6871 - val_loss: 0.6240 - val_accuracy: 0.7200
# Epoch 231/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6471 - accuracy: 0.6871 - val_loss: 0.6266 - val_accuracy: 0.7200
# Epoch 232/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6496 - accuracy: 0.6871 - val_loss: 0.6361 - val_accuracy: 0.7200
# Epoch 233/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6467 - accuracy: 0.6871 - val_loss: 0.6230 - val_accuracy: 0.7200
# Epoch 234/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6458 - accuracy: 0.6871 - val_loss: 0.6241 - val_accuracy: 0.7200
# Epoch 235/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6437 - accuracy: 0.6871 - val_loss: 0.6284 - val_accuracy: 0.7200
# Epoch 236/1000
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6457 - accuracy: 0.6871 - val_loss: 0.6261 - val_accuracy: 0.7200
# Epoch 237/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6414 - accuracy: 0.6871 - val_loss: 0.6223 - val_accuracy: 0.7200
# Epoch 238/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6418 - accuracy: 0.6871 - val_loss: 0.6226 - val_accuracy: 0.7200
# Epoch 239/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6415 - accuracy: 0.6871 - val_loss: 0.6221 - val_accuracy: 0.7200
# Epoch 240/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6431 - accuracy: 0.6871 - val_loss: 0.6250 - val_accuracy: 0.7200
# Epoch 241/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6510 - accuracy: 0.6871 - val_loss: 0.6422 - val_accuracy: 0.7200
# Epoch 242/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6550 - accuracy: 0.6871 - val_loss: 0.6288 - val_accuracy: 0.7200
# Epoch 243/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6550 - accuracy: 0.6871 - val_loss: 0.6411 - val_accuracy: 0.7200
# Epoch 244/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6562 - accuracy: 0.6871 - val_loss: 0.6301 - val_accuracy: 0.7200
# Epoch 245/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6418 - accuracy: 0.6893 - val_loss: 0.6338 - val_accuracy: 0.7200
# Epoch 246/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6456 - accuracy: 0.6871 - val_loss: 0.6418 - val_accuracy: 0.7200
# Epoch 247/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6491 - accuracy: 0.6871 - val_loss: 0.6204 - val_accuracy: 0.7200
# Epoch 248/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6394 - accuracy: 0.6871 - val_loss: 0.6221 - val_accuracy: 0.7200
# Epoch 249/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6407 - accuracy: 0.6871 - val_loss: 0.6204 - val_accuracy: 0.7200
# Epoch 250/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6418 - accuracy: 0.6871 - val_loss: 0.6307 - val_accuracy: 0.7200
# Epoch 251/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6433 - accuracy: 0.6871 - val_loss: 0.6225 - val_accuracy: 0.7200
# Epoch 252/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6514 - accuracy: 0.6871 - val_loss: 0.6335 - val_accuracy: 0.7200
# Epoch 253/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6407 - accuracy: 0.6871 - val_loss: 0.6199 - val_accuracy: 0.7200
# Epoch 254/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6406 - accuracy: 0.6871 - val_loss: 0.6213 - val_accuracy: 0.7200
# Epoch 255/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6424 - accuracy: 0.6871 - val_loss: 0.6456 - val_accuracy: 0.7400
# Epoch 256/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6423 - accuracy: 0.6984 - val_loss: 0.6206 - val_accuracy: 0.7200
# Epoch 257/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6392 - accuracy: 0.6871 - val_loss: 0.6192 - val_accuracy: 0.7200
# Epoch 258/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6382 - accuracy: 0.6871 - val_loss: 0.6268 - val_accuracy: 0.7200
# Epoch 259/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6495 - accuracy: 0.6893 - val_loss: 0.6198 - val_accuracy: 0.7200
# Epoch 260/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6385 - accuracy: 0.6871 - val_loss: 0.6180 - val_accuracy: 0.7200
# Epoch 261/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6458 - accuracy: 0.6871 - val_loss: 0.6377 - val_accuracy: 0.7200
# Epoch 262/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6426 - accuracy: 0.6893 - val_loss: 0.6177 - val_accuracy: 0.7200
# Epoch 263/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6406 - accuracy: 0.6871 - val_loss: 0.6176 - val_accuracy: 0.7200
# Epoch 264/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6390 - accuracy: 0.6871 - val_loss: 0.6205 - val_accuracy: 0.7200
# Epoch 265/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6403 - accuracy: 0.6871 - val_loss: 0.6192 - val_accuracy: 0.7200
# Epoch 266/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6352 - accuracy: 0.6871 - val_loss: 0.6177 - val_accuracy: 0.7200
# Epoch 267/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6371 - accuracy: 0.6871 - val_loss: 0.6361 - val_accuracy: 0.7200
# Epoch 268/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6428 - accuracy: 0.6871 - val_loss: 0.6188 - val_accuracy: 0.7200
# Epoch 269/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6378 - accuracy: 0.6871 - val_loss: 0.6165 - val_accuracy: 0.7200
# Epoch 270/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6392 - accuracy: 0.6871 - val_loss: 0.6294 - val_accuracy: 0.7200
# Epoch 271/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6405 - accuracy: 0.6893 - val_loss: 0.6164 - val_accuracy: 0.7200
# Epoch 272/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6371 - accuracy: 0.6871 - val_loss: 0.6159 - val_accuracy: 0.7200
# Epoch 273/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6394 - accuracy: 0.6893 - val_loss: 0.6451 - val_accuracy: 0.7600
# Epoch 274/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6368 - accuracy: 0.7007 - val_loss: 0.6243 - val_accuracy: 0.7200
# Epoch 275/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6374 - accuracy: 0.6871 - val_loss: 0.6198 - val_accuracy: 0.7200
# Epoch 276/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6449 - accuracy: 0.6916 - val_loss: 0.6219 - val_accuracy: 0.7200
# Epoch 277/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6311 - accuracy: 0.6871 - val_loss: 0.6256 - val_accuracy: 0.7200
# Epoch 278/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6385 - accuracy: 0.6871 - val_loss: 0.6180 - val_accuracy: 0.7200
# Epoch 279/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6425 - accuracy: 0.6984 - val_loss: 0.6260 - val_accuracy: 0.7200
# Epoch 280/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6326 - accuracy: 0.6893 - val_loss: 0.6327 - val_accuracy: 0.7200
# Epoch 281/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6371 - accuracy: 0.6871 - val_loss: 0.6143 - val_accuracy: 0.7200
# Epoch 282/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6351 - accuracy: 0.6939 - val_loss: 0.6223 - val_accuracy: 0.7200
# Epoch 283/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6412 - accuracy: 0.6871 - val_loss: 0.6397 - val_accuracy: 0.7600
# Epoch 284/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6447 - accuracy: 0.6939 - val_loss: 0.6139 - val_accuracy: 0.7200
# Epoch 285/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6346 - accuracy: 0.7029 - val_loss: 0.6201 - val_accuracy: 0.7200
# Epoch 286/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6517 - accuracy: 0.7075 - val_loss: 0.6254 - val_accuracy: 0.7200
# Epoch 287/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6421 - accuracy: 0.6893 - val_loss: 0.6195 - val_accuracy: 0.7200
# Epoch 288/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6337 - accuracy: 0.6871 - val_loss: 0.6141 - val_accuracy: 0.7200
# Epoch 289/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6366 - accuracy: 0.6871 - val_loss: 0.6138 - val_accuracy: 0.7200
# Epoch 290/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6388 - accuracy: 0.7029 - val_loss: 0.6156 - val_accuracy: 0.7200
# Epoch 291/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6413 - accuracy: 0.6916 - val_loss: 0.6133 - val_accuracy: 0.7200
# Epoch 292/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6328 - accuracy: 0.6871 - val_loss: 0.6124 - val_accuracy: 0.7200
# Epoch 293/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6310 - accuracy: 0.6871 - val_loss: 0.6157 - val_accuracy: 0.7200
# Epoch 294/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6342 - accuracy: 0.6871 - val_loss: 0.6230 - val_accuracy: 0.7200
# Epoch 295/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6352 - accuracy: 0.6871 - val_loss: 0.6126 - val_accuracy: 0.7200
# Epoch 296/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6344 - accuracy: 0.6871 - val_loss: 0.6139 - val_accuracy: 0.7200
# Epoch 297/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6334 - accuracy: 0.6871 - val_loss: 0.6204 - val_accuracy: 0.7200
# Epoch 298/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6373 - accuracy: 0.6916 - val_loss: 0.6154 - val_accuracy: 0.7200
# Epoch 299/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6251 - accuracy: 0.6871 - val_loss: 0.6204 - val_accuracy: 0.7200
# Epoch 300/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6444 - accuracy: 0.6871 - val_loss: 0.6122 - val_accuracy: 0.7200
# Epoch 301/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6321 - accuracy: 0.7029 - val_loss: 0.6109 - val_accuracy: 0.7200
# Epoch 302/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6303 - accuracy: 0.6871 - val_loss: 0.6106 - val_accuracy: 0.7200
# Epoch 303/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6286 - accuracy: 0.6871 - val_loss: 0.6125 - val_accuracy: 0.7200
# Epoch 304/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6287 - accuracy: 0.6893 - val_loss: 0.6100 - val_accuracy: 0.7200
# Epoch 305/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6264 - accuracy: 0.6871 - val_loss: 0.6233 - val_accuracy: 0.7400
# Epoch 306/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6323 - accuracy: 0.6984 - val_loss: 0.6097 - val_accuracy: 0.7200
# Epoch 307/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6367 - accuracy: 0.6939 - val_loss: 0.6190 - val_accuracy: 0.7200
# Epoch 308/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6305 - accuracy: 0.6871 - val_loss: 0.6126 - val_accuracy: 0.7200
# Epoch 309/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6267 - accuracy: 0.6871 - val_loss: 0.6091 - val_accuracy: 0.7200
# Epoch 310/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6265 - accuracy: 0.6871 - val_loss: 0.6093 - val_accuracy: 0.7200
# Epoch 311/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6282 - accuracy: 0.6893 - val_loss: 0.6168 - val_accuracy: 0.7200
# Epoch 312/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6267 - accuracy: 0.6916 - val_loss: 0.6117 - val_accuracy: 0.7200
# Epoch 313/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6324 - accuracy: 0.6871 - val_loss: 0.6093 - val_accuracy: 0.7200
# Epoch 314/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6259 - accuracy: 0.6871 - val_loss: 0.6089 - val_accuracy: 0.7200
# Epoch 315/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.6270 - accuracy: 0.6871 - val_loss: 0.6144 - val_accuracy: 0.7200
# Epoch 316/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6348 - accuracy: 0.6893 - val_loss: 0.6078 - val_accuracy: 0.7200
# Epoch 317/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6259 - accuracy: 0.6871 - val_loss: 0.6076 - val_accuracy: 0.7200
# Epoch 318/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6307 - accuracy: 0.6871 - val_loss: 0.6079 - val_accuracy: 0.7200
# Epoch 319/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6269 - accuracy: 0.6916 - val_loss: 0.6099 - val_accuracy: 0.7200
# Epoch 320/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6254 - accuracy: 0.6871 - val_loss: 0.6133 - val_accuracy: 0.7200
# Epoch 321/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6284 - accuracy: 0.6871 - val_loss: 0.6069 - val_accuracy: 0.7200
# Epoch 322/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6257 - accuracy: 0.6871 - val_loss: 0.6072 - val_accuracy: 0.7200
# Epoch 323/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6273 - accuracy: 0.6871 - val_loss: 0.6095 - val_accuracy: 0.7200
# Epoch 324/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6245 - accuracy: 0.6871 - val_loss: 0.6169 - val_accuracy: 0.7600
# Epoch 325/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6252 - accuracy: 0.6893 - val_loss: 0.6061 - val_accuracy: 0.7200
# Epoch 326/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6231 - accuracy: 0.6871 - val_loss: 0.6069 - val_accuracy: 0.7200
# Epoch 327/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6252 - accuracy: 0.6893 - val_loss: 0.6143 - val_accuracy: 0.7400
# Epoch 328/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6423 - accuracy: 0.7007 - val_loss: 0.6420 - val_accuracy: 0.7600
# Epoch 329/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6328 - accuracy: 0.6984 - val_loss: 0.6060 - val_accuracy: 0.7200
# Epoch 330/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6307 - accuracy: 0.7007 - val_loss: 0.6119 - val_accuracy: 0.7200
# Epoch 331/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6355 - accuracy: 0.7188 - val_loss: 0.6111 - val_accuracy: 0.7200
# Epoch 332/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6280 - accuracy: 0.6893 - val_loss: 0.6200 - val_accuracy: 0.7600
# Epoch 333/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6200 - accuracy: 0.6984 - val_loss: 0.6113 - val_accuracy: 0.7200
# Epoch 334/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6255 - accuracy: 0.7029 - val_loss: 0.6095 - val_accuracy: 0.7200
# ...
# Epoch 890/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5439 - accuracy: 0.8027 - val_loss: 0.5612 - val_accuracy: 0.7800
# Epoch 891/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5294 - accuracy: 0.8005 - val_loss: 0.5653 - val_accuracy: 0.7800
# Epoch 892/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5384 - accuracy: 0.7937 - val_loss: 0.5539 - val_accuracy: 0.7800
# Epoch 893/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5447 - accuracy: 0.8027 - val_loss: 0.5673 - val_accuracy: 0.8000
# Epoch 894/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5514 - accuracy: 0.8050 - val_loss: 0.5589 - val_accuracy: 0.7800
# Epoch 895/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5361 - accuracy: 0.7982 - val_loss: 0.5561 - val_accuracy: 0.7800
# Epoch 896/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5353 - accuracy: 0.8005 - val_loss: 0.5560 - val_accuracy: 0.7800
# Epoch 897/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5489 - accuracy: 0.7959 - val_loss: 0.5569 - val_accuracy: 0.7800
# Epoch 898/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5303 - accuracy: 0.8050 - val_loss: 0.5861 - val_accuracy: 0.7800
# Epoch 899/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5522 - accuracy: 0.7982 - val_loss: 0.5612 - val_accuracy: 0.8000
# Epoch 900/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5373 - accuracy: 0.8027 - val_loss: 0.5557 - val_accuracy: 0.7800
# Epoch 901/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5404 - accuracy: 0.7982 - val_loss: 0.5544 - val_accuracy: 0.7800
# Epoch 902/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5356 - accuracy: 0.7982 - val_loss: 0.5674 - val_accuracy: 0.7800
# Epoch 903/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5302 - accuracy: 0.8027 - val_loss: 0.5696 - val_accuracy: 0.8000
# Epoch 904/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5332 - accuracy: 0.7959 - val_loss: 0.5590 - val_accuracy: 0.7800
# Epoch 905/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5331 - accuracy: 0.8005 - val_loss: 0.5550 - val_accuracy: 0.7800
# Epoch 906/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5323 - accuracy: 0.8050 - val_loss: 0.5539 - val_accuracy: 0.7800
# Epoch 907/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5330 - accuracy: 0.8050 - val_loss: 0.5693 - val_accuracy: 0.7800
# Epoch 908/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5330 - accuracy: 0.7959 - val_loss: 0.5561 - val_accuracy: 0.7800
# Epoch 909/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5360 - accuracy: 0.7959 - val_loss: 0.5550 - val_accuracy: 0.7800
# Epoch 910/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5365 - accuracy: 0.8005 - val_loss: 0.5541 - val_accuracy: 0.7800
# Epoch 911/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5327 - accuracy: 0.7982 - val_loss: 0.5540 - val_accuracy: 0.7800
# Epoch 912/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5334 - accuracy: 0.8005 - val_loss: 0.5535 - val_accuracy: 0.7800
# Epoch 913/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5278 - accuracy: 0.8005 - val_loss: 0.5691 - val_accuracy: 0.7800
# Epoch 914/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5348 - accuracy: 0.7959 - val_loss: 0.5563 - val_accuracy: 0.7800
# Epoch 915/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5313 - accuracy: 0.7959 - val_loss: 0.5526 - val_accuracy: 0.7800
# Epoch 916/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5351 - accuracy: 0.7982 - val_loss: 0.5620 - val_accuracy: 0.7800
# Epoch 917/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5430 - accuracy: 0.7982 - val_loss: 0.6009 - val_accuracy: 0.7800
# Epoch 918/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5459 - accuracy: 0.7914 - val_loss: 0.5748 - val_accuracy: 0.7800
# Epoch 919/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5488 - accuracy: 0.7914 - val_loss: 0.5546 - val_accuracy: 0.7800
# Epoch 920/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5336 - accuracy: 0.7982 - val_loss: 0.5585 - val_accuracy: 0.7800
# Epoch 921/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5292 - accuracy: 0.8005 - val_loss: 0.5531 - val_accuracy: 0.7800
# Epoch 922/1000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5349 - accuracy: 0.8005 - val_loss: 0.5536 - val_accuracy: 0.7800
# Epoch 923/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5388 - accuracy: 0.8005 - val_loss: 0.5533 - val_accuracy: 0.7800
# Epoch 924/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5298 - accuracy: 0.7982 - val_loss: 0.5527 - val_accuracy: 0.7800
# Epoch 925/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5329 - accuracy: 0.7959 - val_loss: 0.5709 - val_accuracy: 0.8200
# Epoch 926/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5544 - accuracy: 0.7937 - val_loss: 0.5541 - val_accuracy: 0.7800
# Epoch 927/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5379 - accuracy: 0.7959 - val_loss: 0.5566 - val_accuracy: 0.7800
# Epoch 928/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5430 - accuracy: 0.8005 - val_loss: 0.5609 - val_accuracy: 0.8000
# Epoch 929/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5347 - accuracy: 0.7959 - val_loss: 0.5537 - val_accuracy: 0.7800
# Epoch 930/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5326 - accuracy: 0.8005 - val_loss: 0.5569 - val_accuracy: 0.7800
# Epoch 931/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5289 - accuracy: 0.8027 - val_loss: 0.5785 - val_accuracy: 0.7800
# Epoch 932/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5384 - accuracy: 0.8005 - val_loss: 0.5529 - val_accuracy: 0.7800
# Epoch 933/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5304 - accuracy: 0.7982 - val_loss: 0.5521 - val_accuracy: 0.7800
# Epoch 934/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5294 - accuracy: 0.7982 - val_loss: 0.5526 - val_accuracy: 0.7800
# Epoch 935/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5339 - accuracy: 0.7959 - val_loss: 0.5527 - val_accuracy: 0.7800
# Epoch 936/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5406 - accuracy: 0.8027 - val_loss: 0.5594 - val_accuracy: 0.8000
# Epoch 937/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5322 - accuracy: 0.8005 - val_loss: 0.5549 - val_accuracy: 0.7800
# Epoch 938/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5281 - accuracy: 0.8005 - val_loss: 0.5544 - val_accuracy: 0.7800
# Epoch 939/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5324 - accuracy: 0.7982 - val_loss: 0.5521 - val_accuracy: 0.7800
# Epoch 940/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5287 - accuracy: 0.7959 - val_loss: 0.5536 - val_accuracy: 0.7800
# Epoch 941/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5440 - accuracy: 0.7868 - val_loss: 0.5791 - val_accuracy: 0.7800
# Epoch 942/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5460 - accuracy: 0.7959 - val_loss: 0.5643 - val_accuracy: 0.7800
# Epoch 943/1000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5315 - accuracy: 0.7959 - val_loss: 0.5508 - val_accuracy: 0.7800
# Epoch 944/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5281 - accuracy: 0.8073 - val_loss: 0.5710 - val_accuracy: 0.7800
# Epoch 945/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5364 - accuracy: 0.7982 - val_loss: 0.5657 - val_accuracy: 0.7800
# Epoch 946/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5556 - accuracy: 0.7823 - val_loss: 0.6138 - val_accuracy: 0.7800
# Epoch 947/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5642 - accuracy: 0.7891 - val_loss: 0.5531 - val_accuracy: 0.7800
# Epoch 948/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5516 - accuracy: 0.7914 - val_loss: 0.5537 - val_accuracy: 0.7800
# Epoch 949/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5300 - accuracy: 0.8027 - val_loss: 0.5766 - val_accuracy: 0.7800
# Epoch 950/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5500 - accuracy: 0.7959 - val_loss: 0.5567 - val_accuracy: 0.7800
# Epoch 951/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5424 - accuracy: 0.7937 - val_loss: 0.5570 - val_accuracy: 0.8000
# Epoch 952/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5382 - accuracy: 0.7937 - val_loss: 0.5537 - val_accuracy: 0.7800
# Epoch 953/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5358 - accuracy: 0.8050 - val_loss: 0.5542 - val_accuracy: 0.7800
# Epoch 954/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5441 - accuracy: 0.7959 - val_loss: 0.5525 - val_accuracy: 0.7800
# Epoch 955/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5335 - accuracy: 0.7959 - val_loss: 0.5597 - val_accuracy: 0.8000
# Epoch 956/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5308 - accuracy: 0.7959 - val_loss: 0.5678 - val_accuracy: 0.7800
# Epoch 957/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5530 - accuracy: 0.8005 - val_loss: 0.6176 - val_accuracy: 0.7800
# Epoch 958/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5407 - accuracy: 0.7914 - val_loss: 0.5525 - val_accuracy: 0.7800
# Epoch 959/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5249 - accuracy: 0.7959 - val_loss: 0.5521 - val_accuracy: 0.7800
# Epoch 960/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5268 - accuracy: 0.7959 - val_loss: 0.5524 - val_accuracy: 0.7800
# Epoch 961/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5277 - accuracy: 0.7959 - val_loss: 0.5547 - val_accuracy: 0.7800
# Epoch 962/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5359 - accuracy: 0.7959 - val_loss: 0.5548 - val_accuracy: 0.7800
# Epoch 963/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5370 - accuracy: 0.8005 - val_loss: 0.5539 - val_accuracy: 0.7800
# Epoch 964/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5296 - accuracy: 0.7959 - val_loss: 0.5631 - val_accuracy: 0.7800
# Epoch 965/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5282 - accuracy: 0.7959 - val_loss: 0.5710 - val_accuracy: 0.7800
# Epoch 966/1000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5354 - accuracy: 0.7959 - val_loss: 0.5588 - val_accuracy: 0.7800
# Epoch 967/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5360 - accuracy: 0.7959 - val_loss: 0.5797 - val_accuracy: 0.7800
# Epoch 968/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5301 - accuracy: 0.7982 - val_loss: 0.5508 - val_accuracy: 0.7800
# Epoch 969/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5333 - accuracy: 0.8005 - val_loss: 0.5599 - val_accuracy: 0.8000
# Epoch 970/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5417 - accuracy: 0.7914 - val_loss: 0.5571 - val_accuracy: 0.8000
# Epoch 971/1000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5563 - accuracy: 0.7914 - val_loss: 0.6034 - val_accuracy: 0.7800
# Epoch 972/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5526 - accuracy: 0.7959 - val_loss: 0.5681 - val_accuracy: 0.7800
# Epoch 973/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5346 - accuracy: 0.8005 - val_loss: 0.5508 - val_accuracy: 0.7800
# Epoch 974/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5271 - accuracy: 0.7959 - val_loss: 0.5527 - val_accuracy: 0.7800
# Epoch 975/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5248 - accuracy: 0.7959 - val_loss: 0.5514 - val_accuracy: 0.7800
# Epoch 976/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5278 - accuracy: 0.7982 - val_loss: 0.5581 - val_accuracy: 0.7800
# Epoch 977/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5274 - accuracy: 0.7937 - val_loss: 0.5792 - val_accuracy: 0.7800
# Epoch 978/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5314 - accuracy: 0.7959 - val_loss: 0.5517 - val_accuracy: 0.7800
# Epoch 979/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5307 - accuracy: 0.7959 - val_loss: 0.5513 - val_accuracy: 0.7800
# Epoch 980/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5340 - accuracy: 0.8027 - val_loss: 0.5653 - val_accuracy: 0.7800
# Epoch 981/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5284 - accuracy: 0.7982 - val_loss: 0.5615 - val_accuracy: 0.7800
# Epoch 982/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5324 - accuracy: 0.8005 - val_loss: 0.5617 - val_accuracy: 0.7800
# Epoch 983/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5296 - accuracy: 0.7959 - val_loss: 0.5541 - val_accuracy: 0.7800
# Epoch 984/1000
# 14/14 [==============================] - 0s 7ms/step - loss: 0.5256 - accuracy: 0.7959 - val_loss: 0.5518 - val_accuracy: 0.7800
# Epoch 985/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5356 - accuracy: 0.7959 - val_loss: 0.5688 - val_accuracy: 0.7800
# Epoch 986/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5327 - accuracy: 0.7959 - val_loss: 0.5513 - val_accuracy: 0.7800
# Epoch 987/1000
# 14/14 [==============================] - 0s 10ms/step - loss: 0.5613 - accuracy: 0.7710 - val_loss: 0.6247 - val_accuracy: 0.7800
# Epoch 988/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5698 - accuracy: 0.7891 - val_loss: 0.5513 - val_accuracy: 0.7800
# Epoch 989/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5486 - accuracy: 0.7959 - val_loss: 0.5493 - val_accuracy: 0.7800
# Epoch 990/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5256 - accuracy: 0.7959 - val_loss: 0.5545 - val_accuracy: 0.7800
# Epoch 991/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5262 - accuracy: 0.7982 - val_loss: 0.5515 - val_accuracy: 0.7800
# Epoch 992/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5267 - accuracy: 0.7959 - val_loss: 0.5508 - val_accuracy: 0.7800
# Epoch 993/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5303 - accuracy: 0.8005 - val_loss: 0.5571 - val_accuracy: 0.8000
# Epoch 994/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5683 - accuracy: 0.7868 - val_loss: 0.5651 - val_accuracy: 0.7800
# Epoch 995/1000
# 14/14 [==============================] - 0s 9ms/step - loss: 0.5430 - accuracy: 0.8027 - val_loss: 0.5569 - val_accuracy: 0.7800
# Epoch 996/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5309 - accuracy: 0.7959 - val_loss: 0.5715 - val_accuracy: 0.7800
# Epoch 997/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5276 - accuracy: 0.7959 - val_loss: 0.5543 - val_accuracy: 0.7800
# Epoch 998/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5381 - accuracy: 0.7982 - val_loss: 0.5668 - val_accuracy: 0.8000
# Epoch 999/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5367 - accuracy: 0.7868 - val_loss: 0.5508 - val_accuracy: 0.7800
# Epoch 1000/1000
# 14/14 [==============================] - 0s 8ms/step - loss: 0.5275 - accuracy: 0.8005 - val_loss: 0.5507 - val_accuracy: 0.7800

# %% [markdown]
# Let's take a look at the training history. You probably will need to adjust the parameters like learning rate, batch size, epochs, or even your NN structure.

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
model.evaluate(x_test,y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4863 - accuracy: 0.8537
# [0.4862586557865143, 0.8536585569381714]

# %% [markdown]
# After several adjustion, the results may be still unsatisfying. In this case you will need to take a closer look at your prediction and the true value to see where the problems are. Please manually examine what the mistakes are, and use the technique we learned in the most recent 2 weeks to make some synthetic data to help improve your accuracy in Section 3.4. As a reference, the best accuracy that I can find online using NN is 80%. I was able to improve it to 82.5%. See how accurate you can achieve.

# %%
# Getting predictions for the test set
output = model.predict(x_test)
threshold=0.5
y_pred = np.where(output>=threshold,1,0)
print((y_pred==y_test).sum()/len(y_test))
# Getting accuracy score
for i in range(len(x_test)):
  if y_pred[i,:]<y_test[i,:]:
    print(y_test[i,:],y_pred[i,:],output[i,:], x_test[i,:])
# Out:
# 0.8536585365853658
